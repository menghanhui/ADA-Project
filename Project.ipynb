# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression
from zipfile import ZipFile

# %%
data_folder = './data/'
zip_file = ZipFile(data_folder+'russian-troll-tweets.zip')
fs = {text_file.filename: pd.read_csv(zip_file.open(text_file.filename))
       for text_file in zip_file.infolist()
       if text_file.filename.endswith('.csv')}

# %%
fs['IRAhandle_tweets_1.csv']
# Out:
#         external_author_id      author  \
# 0             9.060000e+17      10_GOP
# 1             9.060000e+17      10_GOP
# 2             9.060000e+17      10_GOP
# 3             9.060000e+17      10_GOP
# 4             9.060000e+17      10_GOP
# 5             9.060000e+17      10_GOP
# 6             9.060000e+17      10_GOP
# 7             9.060000e+17      10_GOP
# 8             9.060000e+17      10_GOP
# 9             9.060000e+17      10_GOP
# 10            9.060000e+17      10_GOP
# 11            9.060000e+17      10_GOP
# 12            9.060000e+17      10_GOP
# 13            9.060000e+17      10_GOP
# 14            9.060000e+17      10_GOP
# 15            9.060000e+17      10_GOP
# 16            9.060000e+17      10_GOP
# 17            9.060000e+17      10_GOP
# 18            9.060000e+17      10_GOP
# 19            9.060000e+17      10_GOP
# 20            9.060000e+17      10_GOP
# 21            9.060000e+17      10_GOP
# 22            9.060000e+17      10_GOP
# ...

# %%
data=pd.DataFrame()
for key,val in fs.items():
    data=pd.concat([data,val])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ita_tweets=data[data.language=='Italian']
us_tweets=data[(data.language=='English') & (data.region=='United States')]

# %%
us_tweets
# Out:
#         external_author_id          author  \
# 0             1.674084e+09      GAB1ALDANA
# 1             1.674084e+09      GAB1ALDANA
# 2             1.674084e+09      GAB1ALDANA
# 4             1.674084e+09      GAB1ALDANA
# 5             1.674084e+09      GAB1ALDANA
# 6             1.674084e+09      GAB1ALDANA
# 7             1.674084e+09      GAB1ALDANA
# 8             1.674084e+09      GAB1ALDANA
# 9             1.674084e+09      GAB1ALDANA
# 10            1.674084e+09      GAB1ALDANA
# 11            1.674084e+09      GAB1ALDANA
# 12            1.674084e+09      GAB1ALDANA
# 13            1.674084e+09      GAB1ALDANA
# 14            1.674084e+09      GAB1ALDANA
# 15            1.674084e+09      GAB1ALDANA
# 16            1.674084e+09      GAB1ALDANA
# 17            1.674084e+09      GAB1ALDANA
# 18            1.674084e+09      GAB1ALDANA
# 19            1.674084e+09      GAB1ALDANA
# 20            1.674084e+09      GAB1ALDANA
# 21            1.674084e+09      GAB1ALDANA
# ...

# %%
ita_tweets
# Out:
#         external_author_id           author  \
# 266           1.674084e+09       GAB1ALDANA
# 316           1.674084e+09       GAB1ALDANA
# 627           1.674084e+09       GAB1ALDANA
# 911           1.674084e+09       GAB1ALDANA
# 942           1.674084e+09       GAB1ALDANA
# 2459          1.504356e+09   GALLOWAYELIANA
# 3008          1.504356e+09   GALLOWAYELIANA
# 5480          1.660771e+09  GARRETTSIMPSON_
# 6921          1.660771e+09  GARRETTSIMPSON_
# 7999          1.660771e+09  GARRETTSIMPSON_
# 9551          8.390000e+17    GATTISILGATTI
# 9552          8.390000e+17    GATTISILGATTI
# 9553          8.390000e+17    GATTISILGATTI
# 9554          8.390000e+17    GATTISILGATTI
# 9555          8.390000e+17    GATTISILGATTI
# 9556          8.390000e+17    GATTISILGATTI
# 9557          8.390000e+17    GATTISILGATTI
# 9558          8.390000e+17    GATTISILGATTI
# 9559          8.390000e+17    GATTISILGATTI
# 9560          8.390000e+17    GATTISILGATTI
# ...
