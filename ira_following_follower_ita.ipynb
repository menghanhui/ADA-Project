# %%
# Put your imports here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
italian_tweets = pd.read_csv('italian_tweets_old.csv')

# %%
italian_tweets['publish_date'] =  pd.to_datetime(italian_tweets['publish_date'], format='%m/%d/%Y %H:%M')
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
list_name = ['ANNAROMAN0','1LORENAFAVA1','GATTISILGATTI','VITTOREGUIDI','FRANNERVIA']
#anna = italian_tweets.loc[italian_tweets['author'] == 'ANNAROMAN0']
#lorena = italian_tweets.loc[italian_tweets['author'] == '1LORENAFAVA1']
#gatti = italian_tweets.loc[italian_tweets['author'] == 'GATTISILGATTI']
#guidi = italian_tweets.loc[italian_tweets['author'] == 'VITTOREGUIDI']
#frann = italian_tweets.loc[italian_tweets['author'] == 'FRANNERVIA']
exq = italian_tweets.loc[italian_tweets['author'] == 'EXQUOTE']
best = italian_tweets[italian_tweets['author'].isin(list_name)]

# %%
#lorena = lorena.sort_values('publish_date', ascending=True)
#gatti = gatti.sort_values('publish_date', ascending=True)
#guidi = guidi.sort_values('publish_date', ascending=True)
#frann = frann.sort_values('publish_date', ascending=True)
exq = exq.sort_values('publish_date', ascending=True)
#anna = anna.sort_values('publish_date', ascending=True)
best = best.sort_values('publish_date', ascending=True)

# %%
fig = plt.figure(figsize=(12, 6))

# iterate the different groups to create a different series
for author, tweet in best.groupby('author'): 
    plt.plot(tweet['publish_date'], tweet['followers'], label=author)

plt.legend(loc='best')


#plt.plot(lorena["publish_date"], lorena["followers"])
#plt.plot(anna["publish_date"], anna["followers"])
#plt.plot(guidi["publish_date"], guidi["followers"])
#plt.plot(frann["publish_date"], frann["followers"])
#plt.plot(gatti["publish_date"], gatti["followers"])
#plt.plot(exq["publish_date"], exq["followers"])
#plt.show()

# %%
fig = plt.figure(figsize=(12, 6))

# iterate the different groups to create a different series
for author, tweet in best.groupby('author'): 
    plt.plot(tweet['publish_date'], tweet['following'], label=author)

plt.legend(loc='best')

# %%
fig = plt.figure(figsize=(12, 6))
plt.plot(exq["publish_date"], exq["followers"])
#plt.plot(exq["publish_date"], exq["following"])

# %%
best_limit = best.loc[best['publish_date'] < '2017-03-10']

# %%
best_limit
# Out:
#         external_author_id         author  \
# 174117        8.390000e+17     ANNAROMAN0
# 174116        8.390000e+17     ANNAROMAN0
# 174118        8.390000e+17     ANNAROMAN0
# 174119        8.390000e+17     ANNAROMAN0
# 1623          8.390000e+17   1LORENAFAVA1
# 1624          8.390000e+17   1LORENAFAVA1
# 10320         8.390000e+17  GATTISILGATTI
# 10321         8.390000e+17  GATTISILGATTI
# 259670        8.390000e+17   VITTOREGUIDI
# 259669        8.390000e+17   VITTOREGUIDI
# 343404        8.390000e+17     FRANNERVIA
# 343405        8.390000e+17     FRANNERVIA
# 343406        8.390000e+17     FRANNERVIA
# 174120        8.390000e+17     ANNAROMAN0
# 174121        8.390000e+17     ANNAROMAN0
# 1626          8.390000e+17   1LORENAFAVA1
# 1627          8.390000e+17   1LORENAFAVA1
# 1628          8.390000e+17   1LORENAFAVA1
# 174123        8.390000e+17     ANNAROMAN0
# 174122        8.390000e+17     ANNAROMAN0
# 1629          8.390000e+17   1LORENAFAVA1
# ...

# %%
fig = plt.figure(figsize=(15, 6))

# iterate the different groups to create a different series
for author, tweet in best_limit.groupby('author'): 
    plt.plot(tweet['publish_date'], tweet['followers'], label=author)

plt.legend(loc='best')

# %%
fig = plt.figure(figsize=(15, 6))

# iterate the different groups to create a different series
for author, tweet in best_limit.groupby('author'): 
    plt.plot(tweet['publish_date'], tweet['following'], label=author)

plt.legend(loc='best')

# %%
italian_tweets_limit = italian_tweets.loc[italian_tweets['publish_date'] > '2015']

# %%
fig = plt.figure(figsize=(15, 6))

# iterate the different groups to create a different series
for author, tweet in italian_tweets_limit.groupby('author'): 
    plt.plot(tweet['publish_date'], tweet['followers'], label=author)

#plt.legend(loc='best')
