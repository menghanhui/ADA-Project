# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
italian_tweets_text = pd.read_csv('italian_tweet_text.csv',header=None)

# %%
stopwords = pd.read_json('stopwords-it.json')

# %%
italian_tweets_text.head()
# Out:
#    0                                                  1
# 0  0  Masterchef il vincitore  Valerio Braschi Maste...
# 1  1  Sternhell ci spiega il nazionalismo razzista e...
# 2  2  httpstcoCHnirfPdLO  I Sioux sono arrivati a Wa...
# 3  3  La stagione  di GamesOfThrones in tv dal  lugl...
# 4  4  Su Left in edicola domani il racconto e le int...

# %%
stopwords = stopwords[0].tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-ea3b99e82433> in <module>()
# ----> 1 stopwords = stopwords[0].tolist()
#       2 stopwords
#
# AttributeError: 'str' object has no attribute 'tolist'

# %%
stopwords
# Out:
# True

# %%
italian_tweets_text.shape[0]
# Out:
# 38630

# %%
list_final = []
for text in italian_tweets_text[1]:
    list_final.append([word.lower() for word in text.split() if (word.lower() not in stopwords and len(word)>4 and word.startswith('http')==False)])
    
list_final
# Out:
# [['masterchef',
#   'vincitore',
#   'valerio',
#   'braschi',
#   'masterchefit',
#   'masterchefit'],
#  ['sternhell', 'spiega', 'nazionalismo', 'razzista', 'socialista', 'marine'],
#  ['sioux',
#   'arrivati',
#   'washington',
#   'marcia',
#   'indiana',
#   'trump',
#   'nativenationsmarchondc'],
#  ['stagione', 'gamesofthrones', 'luglio', 'teaser', 'dellannuncio'],
#  ['edicola',
#   'domani',
#   'racconto',
#   'interviste',
#   'frmaselli',
#   'palchi',
#   'comizi',
#   'francia'],
#  ['consip', 'tiziano', 'renzi', 'autosospende', 'segretario', 'rignano'],
#  ['linkedin',
#   'funziona',
#   'linkedin',
#   'funziona',
#   'linkedinitalia',
#   'linkiesta'],
#  ['morire', 'amazon', 'lecommerce', 'sparire', 'negozi', 'linkiesta'],
#  ['farsi',
#   'chiamare',
#   'direttore',
#   'creativo',
#   'intervista',
#   'oliviero',
#   'toscani',
#   'linkiesta'],
#  ['interatalanta',
#   'gasperini',
#   'vendetta',
#   'sullinter',
#   'sbagliai',
#   'accettare',
#   'lofferta'],
#  ['alstom', 'lanciano', 'aptis', 'soluzione', 'mobilit', 'innovativa'],
#  ['daniesilvestricarmenconsolimaxgazze', 'dellestate'],
#  ['domani',
#   'matteosalvinimi',
#   'napoli',
#   'attivisti',
#   'occupano',
#   'dellevento'],
#  ['trasparenza',
#   'soliti',
#   'partita',
#   'nomine',
#   'unenorme',
#   'occasione',
#   'sprecata',
#   'linkiesta'],
#  ['minacce',
#   'insulti',
#   'ciociara',
#   'pornostar',
#   'infuriare',
#   'prefetto',
#   'frosinone'],
#  ['tiziano', 'renzi', 'lascia', 'segreteria', 'autosospeso', 'rignano'],
#  ['allarme', 'aviaria', 'strage', 'vienna', 'morti', 'pellicani'],
#  ['panico', 'metro', 'folle', 'tenta', 'aggredire', 'donne'],
#  ['torna', 'bimba', 'rapita', 'padre', 'portata', 'siria'],
#  ['statua',
#   'gigante',
#   'ramsesii',
#   'torna',
#   'farci',
#   'sognare',
#   'legitto',
#   'video'],
#  ['italiano',
#   'istruito',
#   'lidentikit',
#   'delluomo',
#   'donne',
#   'cerchidacquami',
#   'legacooplombard'],
#  ['bunjevac', 'salver', 'fumetti'],
#  ['linquinamento',
#   'ambientale',
#   'strage',
#   'bambini',
#   'nostrum',
#   'alessandro',
#   'mauceri',
#   'opsoms',
#   'lavocedinewyork'],
#  ['semplicemente', 'lunico', 'valga', 'ascoltare'],
#  ['gentrification',
#   'unintervista',
#   'autori',
#   'pagine',
#   'facebook',
#   'ironiche',
#   'interessanti'],
#  ['braccia', 'mamma', 'rapita', 'padre', 'siriano'],
#  ['sacerdozio', 'uomini', 'sposati', 'possibilit'],
#  ['napoli',
#   'polemiche',
#   'proteste',
#   'salta',
#   'manifestazione',
#   'matteo',
#   'salvini',
#   'msotra',
#   'doltemare'],
#  ['salvini',
#   'napoli',
#   'interviene',
#   'minniti',
#   'venga',
#   'assicurato',
#   'diritto',
#   'costituzionalmente',
#   'garantito',
#   'manifestare'],
#  ['conti', 'online', 'regole', 'difendersi', 'furti'],
#  ['braccia', 'mamma', 'rapita', 'padre', 'siriano'],
#  ['presentato', 'certificazione', 'unica', 'rischi'],
#  ['soluzione', 'definitiva', 'commenti', 'stupidi', 'articoli'],
#  ['occhio', 'glutenfree', 'aumentare', 'rischio', 'diabete'],
#  ['carico', 'vincitore', 'masterchefit'],
#  ['sharonstone', 'compie', 'scatto', 'spiaggia', 'manda'],
#  ['beppegrillo', 'deroga', 'regola', 'mandati', 'tocca'],
#  ['occidentalis', 'karma', 'radio'],
#  ['donne', 'danzano', 'sembrano', 'statue'],
#  ['bimba', 'rapita', 'arrivata', 'malpensa'],
#  ['edicola',
#   'quotidiano',
#   'marzo',
#   'renzi',
#   'indagati',
#   'suicidi',
#   'magistrati'],
#  ['corea', 'allimpeachment', 'presidente', 'morti', 'manifestazioni'],
#  ['bonus', 'giovani'],
#  ['corona', 'torna', 'commissario', 'propose', 'infiltrato', 'polizia'],
#  ['sudcorea',
#   'corte',
#   'costituzionale',
#   'limpeachment',
#   'presidente',
#   'scontri',
#   'polizia',
#   'manifestanti',
#   'morti'],
#  ['legge', 'povert', 'arriva', 'reddito', 'inclusione', 'spetta'],
#  ['corea', 'presidente'],
#  ['gigliomagico', 'aerei'],
#  ['rimossa', 'presidente', 'corea', 'morti', 'scontri'],
#  ['milan', 'storia', 'infinita', 'closing', 'migliori', 'soldi', 'cinesi'],
#  ['emiliano',
#   'presenta',
#   'programma',
#   'pronto',
#   'adaccordo',
#   'corteggia',
#   'elettori'],
#  ['innovazione',
#   'rivoluzione',
#   'dellautomobile',
#   'cambier',
#   'leuropa',
#   'morire',
#   'linkiesta'],
#  ['rigore'],
#  ['infiltrazioni', 'thohir', 'parla', 'portavoce', 'inter', 'maglianera'],
#  ['youmeher', 'netflixit', 'poliamore', 'banale', 'memorievagina'],
#  ['giudice', 'blocca', 'muslimban', 'fatta', 'entrare', 'famiglia', 'siriana'],
#  ['milano',
#   'perde',
#   'chiavi',
#   'tombino',
#   'muore',
#   'annegato',
#   'tenta',
#   'recuperarle'],
#  ['siria', 'attentato', 'cuore', 'damasco', 'bilancio', 'morti'],
#  ['italiafrancia', 'rugby'],
#  ['libert',
#   'despressione',
#   'salvininapoli',
#   'salvini',
#   'napoli',
#   'paradiso',
#   'inferno'],
#  ['tensione',
#   'paesi',
#   'bassi',
#   'turchia',
#   'lannullamento',
#   'visita',
#   'esteri',
#   'turco',
#   'rotterdam'],
#  ['skyatlantic', 'racconto', 'dellindagine', 'sullomicidio', 'yaragambirasio'],
#  ['tenta', 'recupero', 'chiavi', 'ventenne', 'annega', 'tombino'],
#  ['perch', 'trump', 'nominato', 'jonhuntsman', 'ambasciatore', 'mosca'],
#  ['trainspotting', 'reduci'],
#  ['carestia', 'terribile', 'morendo', 'manca', 'acqua', 'potabile'],
#  ['lavorare', 'apple', 'offerte'],
#  ['denatalit', 'liberi', 'schiavit', 'figli', 'angosciati'],
#  ['rugby', 'italia', 'nazioni', 'francia', 'vince', 'azzurri', 'vincono'],
#  ['pensate', 'clitoride', 'piccolo', 'semino', 'vedete', 'libri', 'sbagliate'],
#  ['londra',
#   'uscir',
#   'dalleuratom',
#   'centrali',
#   'sanit',
#   'riscrivere',
#   'accordo'],
#  ['broker',
#   'scomparso',
#   'truffa',
#   'carpito',
#   'buona',
#   'clienti',
#   'anziani',
#   'denunce'],
#  ['francescocosta',
#   'andato',
#   'michigan',
#   'raccontato',
#   'puntata',
#   'davvero',
#   'bella',
#   'spoiler',
#   'robocop'],
#  ['palermo', 'clochard', 'bruciato', 'fermato'],
#  ['clochard', 'bruciato', 'palermo', 'fermo'],
#  ['perch',
#   'elezioni',
#   'francesi',
#   'olandesi',
#   'tedesche',
#   'riguardano',
#   'conflitti',
#   'europee',
#   'assomigliano'],
#  ['diretta', 'serie', 'campo', 'genoasampdoria', 'fotohttpowlyowodowhk'],
#  ['scampia', 'nuove', 'periferie', 'disastro'],
#  ['perch',
#   'litalia',
#   'conta',
#   'video',
#   'dellatto',
#   'finale',
#   'limesfestival',
#   'lucio',
#   'caracciolo',
#   'diamanti'],
#  ['napoli', 'scontri', 'corteo', 'antisalvini', 'molotov', 'polizia'],
#  ['procuratore', 'licenziato'],
#  ['crolla', 'cavalcavia', 'unitalia', 'pezzi'],
#  ['salvini', 'napoli', 'arresti', 'denunce'],
#  ['charleston',
#   'martina',
#   'stella',
#   'infortunata',
#   'ballandoconlestelle',
#   'brividi'],
#  ['serie', 'genoasampdoria'],
#  ['legge', 'povert', 'arriva', 'reddito', 'inclusione', 'spetta'],
#  ['pedofilo', 'palco', 'factor', 'provino'],
#  ['spalletti', 'firmato', 'precontratto'],
#  ['attenti', 'napoletani', 'bufera', 'cartello', 'supermercato'],
#  ['peanuts', 'marzo'],
#  ['video', 'controverso', 'rigore', 'juventusmilan'],
#  ['pedofilo', 'palco', 'factor', 'provino'],
#  ['valle',
#   'daosta',
#   'presidente',
#   'regionale',
#   'pierluigi',
#   'marquis',
#   'sostenuto',
#   'forze',
#   'autonomiste',
#   'sostit'],
#  ['matteosalvinimi',
#   'napoli',
#   'mostra',
#   'oltremare',
#   'autorizza',
#   'ingresso',
#   'convention'],
#  ['convention',
#   'aperta',
#   'lingotto',
#   'leader',
#   'centrosinistradestra',
#   'matteo',
#   'renzusconi'],
#  ['apontremoli',
#   'dipende',
#   'italiani',
#   'campioni',
#   'mondiali',
#   'alibi',
#   'fcancellato'],
#  ['clochard', 'bruciato', 'palermo', 'video', 'conferma', 'omicidio'],
#  ['chiamparino',
#   'lingotto',
#   'vigliacco',
#   'cambia',
#   'casacca',
#   'cambia',
#   'vento'],
#  ['chicago', 'fiume', 'verde', 'vista', 'parata', 'patrizio', 'video'],
#  ['chailly',
#   'toscanini',
#   'cambiato',
#   'mestiere',
#   'direttore',
#   'dorchestra',
#   'intervista',
#   'teatroallascala'],
#  ['bavaglio',
#   'renzi',
#   'lotti',
#   'indagati',
#   'avvisi',
#   'garanzia',
#   'segreti',
#   'continua',
#   'fattoquotidiano',
#   'marzo'],
#  ['loccidente',
#   'tecnologia',
#   'finanza',
#   'impedire',
#   'declino',
#   'alessandro',
#   'pansa'],
#  ['salvini',
#   'napoli',
#   'minniti',
#   'diritto',
#   'parola',
#   'avversario',
#   'radicale'],
#  ['mucche', 'barbecue', 'futures'],
#  ['sgomberi',
#   'frutto',
#   'politica',
#   'inefficace',
#   'debole',
#   'scrive',
#   'christian',
#   'raimo'],
#  ['facebook',
#   'chiude',
#   'sesso',
#   'droga',
#   'pastorizia',
#   'selvaggia',
#   'lucarelli',
#   'ricoperta',
#   'insulti'],
#  ['almeno', 'morti', 'frana', 'discarica', 'addis', 'abeba', 'etiopia'],
#  ['lingotto',
#   'chiude',
#   'saluto',
#   'palco',
#   'volontari',
#   'renzi',
#   'paologentiloni'],
#  ['giulianopisapia', 'allitalia', 'servono', 'migranti'],
#  ['nuova', 'bufera', 'fillon', 'abiti', 'regalo'],
#  ['assente', 'democrazia', 'frerspamer', 'lavocedinewyork'],
#  ['migranti', 'minniti', 'accoglieremo', 'scappa', 'guerra'],
#  ['pisapia', 'inmezzora', 'replica', 'renzi', 'marca', 'distanza'],
#  ['decolla', 'atterra', 'tetto', 'video'],
#  ['seriea',
#   'interatalanta',
#   'tripletta',
#   'icardi',
#   'banega',
#   'nerazzurri',
#   'quarti',
#   'vittorie',
#   'napoli',
#   'chievo',
#   'udinese',
#   'viola'],
#  ['stasera', 'ignoto', 'unindagine'],
#  ['delrio',
#   'matteorenzi',
#   'maradona',
#   'napoli',
#   'vinceva',
#   'scudetto',
#   'video'],
#  ['orfini', 'sinistra'],
#  ['ironia',
#   'napoli',
#   'fallo',
#   'insigne',
#   'esposto',
#   'striscione',
#   'rigore',
#   'napolicrotone'],
#  ['scheda'],
#  ['arriva', 'primavera', 'assistere', 'fioritura'],
#  ['erdogan',
#   'olanda',
#   'nazista',
#   'bandiera',
#   'turca',
#   'sventola',
#   'consolato'],
#  ['spiriti',
#   'fantasmi',
#   'presidente',
#   'brasiliano',
#   'michel',
#   'temer',
#   'giovane',
#   'moglie',
#   'cambiano',
#   'brasile'],
#  ['wilders', 'cominciata', 'pochi', 'sparir'],
#  ['valanga', 'inter', 'napoli', 'zeman'],
#  ['naomicampbell', 'fabiofazio'],
#  ['pontifexit', 'bambini', 'piace', 'vedermi', 'brutto'],
#  ['italiani', 'mangiano', 'carne', 'allanno'],
#  ['serie', 'palermoroma'],
#  ['migranti', 'minniti', 'accoglieremo', 'scappa', 'guerra'],
#  ['decolla', 'atterra', 'tetto', 'video'],
#  ['abbandonato', 'schettino', 'difende', 'youtube'],
#  ['edicola',
#   'quotidiano',
#   'marzo',
#   'renzi',
#   'rimuovere',
#   'linchiesta',
#   'consip',
#   'provocatoriamente'],
#  ['ministra',
#   'turchia',
#   'famiglia',
#   'scortata',
#   'olanda',
#   'confine',
#   'germania',
#   'calpestati',
#   'diritti',
#   'democratici',
#   'umani'],
#  ['accadeoggi', 'principali', 'avvenimenti', 'previsti', 'marzo'],
#  ['banche',
#   'arriva',
#   'conto',
#   'gratis',
#   'poveri',
#   'recepisce',
#   'norme',
#   'operazioni',
#   'semplici',
#   'bancomat'],
#  ['imposte',
#   'eludono',
#   'giganti',
#   'perch',
#   'riescono',
#   'possiamo',
#   'evitarlo'],
#  ['soliti',
#   'violenti',
#   'distruggono',
#   'napoli',
#   'capitale',
#   'babygang',
#   'legge',
#   'ladri',
#   'aspettiamo',
#   'edicola',
#   'buongiorno'],
#  ['prime', 'pagine'],
#  ['tagli', 'tasse', 'mazzata'],
#  ['feltrinelli', 'giangiacomo', 'ucciso', 'sapeva', 'gladio'],
#  ['video', 'dellanalista', 'interrotto', 'figli', 'triste'],
#  ['sinistra',
#   'riconoscere',
#   'palestina',
#   'chiede',
#   'mozione',
#   'ferreropaolo',
#   'eleonoraforenza'],
#  ['trump', 'russia', 'spiegato'],
#  ['video', 'dellanalista', 'interrotto', 'figli', 'triste', 'ilpost'],
#  ['scontri',
#   'napoli',
#   'lingotto',
#   'solidariet',
#   'salvini',
#   'diritto',
#   'parlare'],
#  ['meteo', 'linverno', 'finito', 'settimana', 'colpo'],
#  ['perch', 'credere', 'renzi', 'listat', 'andrea', 'monaco'],
#  ['intervista', 'chailly', 'statigenerali', 'teatroallascala'],
#  ['trasparenza',
#   'soliti',
#   'partita',
#   'nomine',
#   'unenorme',
#   'occasione',
#   'sprecata',
#   'linkiesta'],
#  ['mccain', 'incalza', 'trump', 'prove', 'obama'],
#  ['berlino', 'cinquemila', 'manifestano', 'celebrare', 'leuropa'],
#  ['ambito',
#   'londra',
#   'riformulare',
#   'decine',
#   'accordi',
#   'sicurezza',
#   'ricerca'],
#  ['serve',
#   'fakenews',
#   'fakepolitics',
#   'ristabilire',
#   'onestculturale',
#   'politica',
#   'abbonati'],
#  ['linter', 'linchiesta', 'bellezza', 'unalba', 'tragica', 'linkiesta'],
#  ['matrimonio', 'rubrica', 'daddy', 'claudiomarcelli'],
#  ['cosmopolita',
#   'ambientalista',
#   'europeista',
#   'jesse',
#   'klaver',
#   'justin',
#   'trudeau',
#   'olandese',
#   'ilbrontolo'],
#  ['postura',
#   'trump',
#   'leuropa',
#   'difficile',
#   'decifrare',
#   'riavvicinamento',
#   'russia',
#   'alterne'],
#  ['rottamazione', 'finita', 'renzi', 'politico', 'palloso', 'linkiesta'],
#  ['business',
#   'ricco',
#   'innovativo',
#   'pochi',
#   'molte',
#   'grigie',
#   'focus',
#   'leliosimi'],
#  ['riham', 'giovane', 'comica', 'ribelle', 'risata', 'protesta'],
#  ['napoli',
#   'demagistris',
#   'difende',
#   'appoggiato',
#   'violenti',
#   'lancia',
#   'lallarme',
#   'sottovalutate',
#   'salvini'],
#  ['matteo',
#   'villala',
#   'polonia',
#   'vuole',
#   'tentare',
#   'reinterpretare',
#   'lunione',
#   'consiglioue',
#   'donaldtusk'],
#  ['juventusfc', 'cerca', 'talenti', 'calciatori', 'posizioni', 'aperte'],
#  ['ladro', 'ucciso', 'dubbi', 'versione', 'ristoratore', 'sentito', 'spari'],
#  ['storia',
#   'vagina',
#   'oggetto',
#   'desiderio',
#   'simbolo',
#   'guerra',
#   'politica',
#   'sciandi'],
#  ['libro',
#   'lussuria',
#   'denuncia',
#   'omissioni',
#   'chiesa',
#   'lotta',
#   'pedofilia'],
#  ['europa', 'litalia', 'reato', 'tortura'],
#  ['movimentoarturo', 'nasce', 'fenomeno', 'social'],
#  ['allegri', 'attaccabile', 'milan', 'vinto', 'meritatamente'],
#  ['starbucks', 'italia', 'benedizione', 'parola', 'piccolo', 'produttore'],
#  ['afghanistan',
#   'dimenticato',
#   'sparito',
#   'radar',
#   'media',
#   'mainstream',
#   'antonella',
#   'napoli'],
#  ['sciopero', 'marzo'],
#  ['american',
#   'sniper',
#   'storia',
#   'miglior',
#   'cecchino',
#   'dellesercito',
#   'statunitense'],
#  ['frigorifero', 'pidiota', 'piaga', 'dellhate', 'speech', 'salamidafabio'],
#  ['alzheimer', 'diagnosi'],
#  ['juvemilan', 'campo', 'codacons'],
#  ['utero', 'affitto', 'giorgiameloni', 'cristiano', 'figli', 'carte', 'nuova'],
#  ['decolla', 'atterra', 'tetto', 'video'],
#  ['condanna', 'dellex', 'presidente', 'catalogna'],
#  ['trump',
#   'spiato',
#   'forni',
#   'microonde',
#   'lallarme',
#   'surreale',
#   'consigliere'],
#  ['scoperte', 'abruzzo', 'impronte', 'dinosauro', 'vecchie', 'video'],
#  ['attenzione', 'banane', 'rischiano', 'scomparire'],
#  ['edicola',
#   'quotidiano',
#   'marzo',
#   'presidente',
#   'dobbiamo',
#   'sconfiggere',
#   'nemici',
#   'ribelli'],
#  ['sorella', 'morte', 'lalba', 'rituale', 'francesco', 'sardo'],
#  ['attenti', 'mucca', 'zampe', 'marine', 'teresa', 'marchesi'],
#  ['settima', 'pilastro', 'politica', 'europea', 'fbagnolirossi'],
#  ['lezioni', 'sentimentali', 'istanbul', 'ozpetek', 'milene', 'mucci'],
#  ['bonus', 'ristrutturazioni', 'novit', 'leggi'],
#  ['facebook',
#   'chiude',
#   'sessodrogaepastorizia',
#   'selvaggia',
#   'lucarelli',
#   'ricoperta',
#   'insulti'],
#  ['prime', 'pagine'],
#  ['lingotto',
#   'lultimo',
#   'naufragio',
#   'vigliacco',
#   'spalle',
#   'dissidenti',
#   'renzi',
#   'titanic'],
#  ['renzi',
#   'rotamadr',
#   'maradona',
#   'forma',
#   'daicheverde',
#   'rubrica',
#   'liaceli'],
#  ['riforma', 'giustizia', 'risparmiare', 'cancellano', 'tribunali', 'minori'],
#  ['testare', 'hotel', 'stelle', 'startup', 'cerca'],
#  ['rivoluzione', 'dellautomobile', 'cambier', 'leuropa', 'morire'],
#  ['scherzo', 'fedez', 'rapper', 'scoppia', 'lacrime'],
#  ['regalo', 'rossa', 'toscana', 'partigiani'],
#  ['lisola',
#   'israele',
#   'largo',
#   'notizie',
#   'lunedi',
#   'medio',
#   'oriente',
#   'sirialibano'],
#  ['scontri',
#   'napoli',
#   'corteo',
#   'antisalvini',
#   'liberi',
#   'manifestanti',
#   'fermati',
#   'processo',
#   'maggio'],
#  ['voucher', 'funzionano'],
#  ['briatore', 'luisellacost', 'vattene', 'video'],
#  ['cambier', 'regolamento', 'dublino', 'diritto', 'dasilo', 'europeo'],
#  ['ragazzo', 'giannimorandi', 'ragazzi', 'speciali', 'palco', 'bologna'],
#  ['fedeli', 'contestata', 'sapienza', 'tafferugli', 'studenti', 'polizia'],
#  ['merkel', 'prepara', 'incontrare', 'trump', 'leggendo', 'playboy'],
#  ['bretagna', 'regno', 'tenuto', 'unito', 'sputo', 'gabrielecarrer'],
#  ['donne', 'intelligenti', 'sanzionato', 'sospeso', 'eurodeputato', 'polacco'],
#  ['missitalia', 'muore', 'finalista', 'veronicasogni'],
#  ['giallo', 'firenze', 'scoperto', 'cadavere', 'donna', 'abbandonata'],
#  ['panda', 'natural', 'power', 'sperimenta', 'biometano', 'ciclo', 'idrico'],
#  ['fiera',
#   'felice',
#   'contribuire',
#   'progetto',
#   'italiani',
#   'altra',
#   'origine',
#   'tante',
#   'storie',
#   'leggere'],
#  ['pensioni', 'conguagli', 'impazziti', 'assegni', 'azzerati', 'anomalia'],
#  ['elisir', 'lunga', 'farmaci', 'studio', 'linvecchiamento'],
#  ['lisis', 'attacco', 'fakes'],
#  ['privatizzazione',
#   'cassa',
#   'depositi',
#   'prestiti',
#   'forti',
#   'dieci',
#   'notizie',
#   'finanziarie',
#   'settimana'],
#  ['vassily',
#   'kandinsky',
#   'mostra',
#   'milano',
#   'astratta',
#   'stanza',
#   'piena',
#   'zeppa'],
#  ['falcone',
#   'borsellino',
#   'chiamateli',
#   'magistrati',
#   'lanima',
#   'interv',
#   'giudice',
#   'alessandra',
#   'camassa',
#   'mafia'],
#  ['libri',
#   'amati',
#   'quentin',
#   'blake',
#   'realizzarlo',
#   'arteprima',
#   'piccolo',
#   'studio',
#   'genovese'],
#  ['milan', 'accordo', 'cinesi', 'closing', 'aprile'],
#  ['trump', 'aumenta', 'dimezza', 'finanziamenti', 'allonu'],
#  ['referendum', 'maggio', 'pagano', 'voucher', 'pensione'],
#  ['champions',
#   'league',
#   'ritorno',
#   'ottavi',
#   'finale',
#   'juventusporto',
#   'segui',
#   'diretta'],
#  ['riscaldamento', 'calcolare', 'spese', 'condomini'],
#  ['superenalotto', 'jackpot'],
#  ['italiani', 'estinguendo', 'vedere', 'ragione', 'lorenzin'],
#  ['crisi',
#   'turchiaolanda',
#   'rterdogan',
#   'conosciamo',
#   'massacro',
#   'srebrenica'],
#  ['riscaldamento', 'calcolare', 'spese', 'condomini'],
#  ['birra', 'minchia', 'culoampcamicia', 'marchi', 'trash', 'allufficio'],
#  ['romalione', 'scatta', 'loperazione', 'remuntada', 'biglietti', 'sconto'],
#  ['motivo', 'vichinghi', 'partivano', 'donne'],
#  ['colazione',
#   'arrampicata',
#   'microappartamento',
#   'ruote',
#   'porti',
#   'gallery'],
#  ['alleanza',
#   'terapeutica',
#   'persona',
#   'legge',
#   'urgente',
#   'marisa',
#   'nicchi'],
#  ['edicola',
#   'quotidiano',
#   'marzo',
#   'lotti',
#   'conversazioni',
#   'marroni',
#   'ritratta'],
#  ['banche', 'arriva', 'conto', 'corrente', 'obbligatorio', 'gratis', 'poveri'],
#  ['riforma', 'giustizia', 'cambia'],
#  ['siberia', 'ghiaccio', 'video'],
#  ['frutta', 'brutta', 'buona', 'piace', 'consumatori'],
#  ['incorna',
#   'locchio',
#   'vetro',
#   'matador',
#   'schizza',
#   'singolare',
#   'incidente',
#   'corrida',
#   'valencia',
#   'video'],
#  ['copertine', 'marzo'],
#  ['riforma', 'giustizia', 'cambia'],
#  ['vaccini', 'meningococco', 'varicella', 'neonati', 'entro'],
#  ['voucher', 'referendum', 'maggio'],
#  ['primavera', 'caldo', 'gradi'],
#  ['paola',
#   'barale',
#   'rimane',
#   'honduras',
#   'dorme',
#   'moreno',
#   'rientra',
#   'nominati',
#   'degan',
#   'susinna',
#   'grimaldi',
#   'isoladeifamosi'],
#  ['francesco', 'toglie', 'gravissimo'],
#  ['ritorno',
#   'dellodio',
#   'leditoriale',
#   'carmelopalma',
#   'nuova',
#   'monografia',
#   'strade'],
#  ['video',
#   'questione',
#   'karma',
#   'germano',
#   'fabio',
#   'deluigi',
#   'improbabili',
#   'padre',
#   'figlio',
#   'marcospagnoli'],
#  ['trumpcare', 'moribondo'],
#  ['voucher', 'boeri', 'limitarli', 'famiglie', 'cancellarli'],
#  ['appalti',
#   'truccati',
#   'sanit',
#   'arresti',
#   'indagato',
#   'traffico',
#   'dinfluenze',
#   'senatore',
#   'angelucci'],
#  ['canzoni', 'famose', 'realt', 'cover', 'sapevi'],
#  ['politica',
#   'colori',
#   'perch',
#   'scelte',
#   'cromatiche',
#   'valgono',
#   'simbolo',
#   'lanalisi',
#   'gcomin'],
#  ['whatsapp', 'video', 'scatena', 'panico'],
#  ['terremoto', 'amatrice', 'protesta', 'consegna', 'prime', 'casette'],
#  ['neanche', 'vibratori', 'fidarti'],
#  ['trailer', 'cattivissimo'],
#  ['figli', 'badanti', 'lasciano', 'litalia', 'costruirsi', 'romania'],
#  ['turchia', 'erdogan', 'spirito', 'fascismo', 'dilaga', 'europa'],
#  ['juventus',
#   'antimafia',
#   'accuse',
#   'contatti',
#   'legate',
#   'criminalit',
#   'organizzata'],
#  ['tulsi',
#   'gabbard',
#   'stella',
#   'cresce',
#   'popolarit',
#   'indisciplinata',
#   'rappresentate',
#   'democratica',
#   'hawaiana'],
#  ['ladro',
#   'sottrae',
#   'destrezza',
#   'cellulare',
#   'galeotta',
#   'scala',
#   'mobile',
#   'video',
#   'furti'],
#  ['stalle', 'stelle', 'regole', 'ricominciare', 'centodiecimcu'],
#  ['ospedali', 'guerra', 'bersaglio', 'attacchi', 'diretta', 'msfitalia'],
#  ['giornata',
#   'dellacqua',
#   'braccialetto',
#   'antispreco',
#   'legambiente',
#   'lavano',
#   'denti'],
#  ['biagio', 'conte', 'palermo', 'amatrice', 'portare', 'speranza'],
#  ['strana', 'storia', 'bambino', 'diventata', 'hitler', 'piccolo'],
#  ['calcio',
#   'criminalit',
#   'lantimafia',
#   'vuole',
#   'ascoltare',
#   'andrea',
#   'agnelli'],
#  ['difender',
#   'lotti',
#   'parlare',
#   'marucci',
#   'toscanissimo',
#   'benefattore',
#   'fondazione',
#   'effetti',
#   'idoneo'],
#  ['coppa', 'discesa'],
#  ['cominciate',
#   'senato',
#   'votazioni',
#   'mozione',
#   'sfiducia',
#   'presentata',
#   'cinquestellecontro',
#   'lotti'],
#  ['scrittura', 'psiche', 'quaderno', 'proibito', 'cspedes', 'acolpidipenna'],
#  ['nutrienti',
#   'gustosi',
#   'pregiudizio',
#   'snobbiamo',
#   'insetti',
#   'tavola',
#   'risposta',
#   'edicola',
#   'digitale'],
#  ['movimentoarturo', 'nasce', 'fenomeno', 'social'],
#  ['mediasetvivendi', 'silvio', 'trattativa'],
#  ['olanda', 'vento', 'populismo', 'guidopetrangeli'],
#  ['trump', 'tasse', 'reddito'],
#  ['telefonia', 'fissa', 'recedere', 'penali'],
#  ['milano', 'affonda', 'staminali', 'cancro', 'farmaco', 'promettente'],
#  ['distrutto', 'poesia', 'vecchio', 'scimmione', 'fulvioabbate'],
#  ['elezioniolanda', 'testa', 'partito', 'premier', 'rutte'],
#  ['viaggio', 'qaraqosh', 'dallisis', 'irenecostantini'],
#  ['cirquedusoleil', 'quinte', 'amaluna', 'presto', 'video', 'backstage'],
#  ['cercasi', 'medici', 'matera', 'candida'],
#  ['telefonia', 'fissa', 'recedere', 'penali'],
#  ['guadagna', 'trump', 'rivelata', 'dichiarazione', 'redditi'],
#  ['edicola', 'quotidiano', 'marzo', 'lotti', 'respinta', 'sfiducia', 'renzi'],
#  ['politica',
#   'scouting',
#   'casting',
#   'scegliere',
#   'migliori',
#   'talent',
#   'roberto',
#   'rossini'],
#  ['bagaglio', 'lingotto', 'mazzeo'],
#  ['bergoglio', 'parole', 'semplici', 'gesti', 'forti', 'padre', 'fortunato'],
#  ['spento', 'musica', 'deborahdirani'],
#  ['voucher', 'funzionano'],
#  ['impresa', 'leicester', 'siviglia', 'qualificazione', 'quarti', 'champions'],
#  ['dallingresso',
#   'lotti',
#   'indebolito',
#   'accerchiato',
#   'fuoriusciti',
#   'mirino'],
#  ['famiglia',
#   'robertkelly',
#   'racconta',
#   'video',
#   'virale',
#   'dellintervista',
#   'interrotta'],
#  ['albinati',
#   'perch',
#   'letteratura',
#   'cinema',
#   'italia',
#   'paura',
#   'verit',
#   'linkiesta'],
#  ['perch', 'giocare', 'derby', 'milano', 'sabato', 'scelta', 'migliore'],
#  ['debito', 'millenials', 'linkiesta'],
#  ['challengeaccepted',
#   'accettare',
#   'sfide',
#   'sciacalli',
#   'speculano',
#   'malati',
#   'cancro',
#   'linkiesta',
#   'socialmedia'],
#  ['emiliano', 'caccia', 'grillino', 'vaccini'],
#  ['offende',
#   'lolanda',
#   'offende',
#   'tajani',
#   'juncker',
#   'erdogan',
#   'gentiloni',
#   'insiste',
#   'velocit'],
#  ['uscito', 'bimestrale', 'strade', 'ritorno', 'dellodio'],
#  ['usail', 'bando', 'trump', 'bloccato', 'giudice', 'hawaii'],
#  ['marocco', 'revoca', 'mandato', 'premier'],
#  ['schiaffi', 'insulti', 'bambini', 'insegnante', 'sospesa'],
#  ['linguaggi', 'luomo', 'parla', 'gesti', 'parole'],
#  ['sanit', 'addio', 'ticket', 'funziona', 'esente'],
#  ['vittoria', 'storica', 'maori', 'fiume', 'sacro', 'personalit', 'giuridica'],
#  ['controinchiesta', 'rivela', 'elementi', 'angelamauro', 'aldomoro'],
#  ['grillo', 'trasparenza', 'comico', 'evita', 'responsabilit'],
#  ['andrea',
#   'pontremoli',
#   'dipende',
#   'italiani',
#   'campioni',
#   'mondiali',
#   'alibi',
#   'linkiesta'],
#  ['beppe', 'grillo', 'esiste', 'davvero'],
#  ['lautolettura', 'risparmiare', 'davvero'],
#  ['falla', 'whatsapp', 'telegram', 'rubarti', 'laccount'],
#  ['visco',
#   'preoccupato',
#   'loccupazione',
#   'bacchetta',
#   'governi',
#   'italiani',
#   'compiti'],
#  ['regina', 'elisabetta', 'firmato', 'legge', 'libera', 'brexit'],
#  ['raggi', 'mercato', 'rionale', 'sangiovanni', 'vuoto', 'video'],
#  ['opere', 'darte', 'nascosta', 'depositi', 'musei'],
#  ['centristi',
#   'tornati',
#   'sognano',
#   'balena',
#   'bianca',
#   'ilbrontolo',
#   'mmarcosarti'],
#  ['lesperto', 'tragedia', 'accade', 'incontra'],
#  ['ferrero',
#   'compra',
#   'fanniemay',
#   'azienda',
#   'leader',
#   'dolci',
#   'cioccolato'],
#  ['budget',
#   'trump',
#   'ridotti',
#   'allosso',
#   'fondi',
#   'ambiente',
#   'ricerca',
#   'cultura',
#   'media',
#   'giuliabelard'],
#  ['grandi',
#   'manovre',
#   'centro',
#   'lavvicinarsi',
#   'elezioni',
#   'berlusconiani',
#   'devono',
#   'riorganizzarsi',
#   'trovare',
#   'nuova'],
#  ['settimanadelcaff',
#   'miscelastrategica',
#   'analizza',
#   'prospettive',
#   'usnavy'],
#  ['finmeccanica',
#   'appropriazioni',
#   'indebita',
#   'tasse',
#   'evase',
#   'indagati',
#   'dipendenti',
#   'vertici'],
#  ['heather', 'parisi', 'genitorinonni', 'sentenza', 'inumana', 'abominevole'],
#  ['benaffleck', 'facebook', 'disintossicato', 'dallalcool'],
#  ['dormir', 'nellhotel', 'banksy', 'betlemme', 'giulsdellepiane'],
#  ['esplosione', 'metri', 'feriti', 'escursionisti'],
#  ['trump', 'cerca', 'dollari', 'messico'],
#  ['spazio', 'brinda', 'prime', 'immagini', 'satellite', 'sentinelb'],
#  ['violenta',
#   'esplosione',
#   'cratere',
#   'materiale',
#   'lavico',
#   'colpisce',
#   'turisti',
#   'ricercatori',
#   'video'],
#  ['letterabomba',
#   'parigina',
#   'dellfmi',
#   'ferito',
#   'spedita',
#   'anarchici',
#   'greci'],
#  ['gestione', 'cattiva', 'ilpost'],
#  ['europaleague', 'diretta', 'romalione', 'pallotta', 'capitale', 'segui'],
#  ['strano',
#   'suicidio',
#   'radarista',
#   'testimone',
#   'ustica',
#   'procura',
#   'riesuma',
#   'corpo'],
#  ['domande', 'asilo', 'europa'],
#  ['trumpbudget',
#   'affonda',
#   'lagenzia',
#   'lambiente',
#   'cherchez',
#   'scott',
#   'pruitt',
#   'alessandro',
#   'mauceri',
#   'clima'],
#  ['siria', 'aereo', 'moschea', 'idlib', 'morti', 'civili'],
#  ['voucher',
#   'aboliti',
#   'maggioranza',
#   'chiude',
#   'questione',
#   'referendum',
#   'referendumlavoro'],
#  ['europaleague',
#   'romalione',
#   'risultato',
#   'ribaltare',
#   'andata',
#   'giallorossi',
#   'francesi',
#   'quarti'],
#  ['corrispondenza', 'esplosiva', 'grecia', 'statigenerali'],
#  ['notevoli'],
#  ['referendum',
#   'voucher',
#   'commissione',
#   'buonilavoro',
#   'pronto',
#   'decreto',
#   'venerd',
#   'voter'],
#  ['lofficialasroma',
#   'sfiora',
#   'rimonta',
#   'lione',
#   'europaleague',
#   'romalione',
#   'erikamenghi'],
#  ['arriva', 'lassegno', 'ricollocazione', 'disoccupati'],
#  ['italia', 'regina', 'corna', 'paesi', 'tradisce'],
#  ['olanda', 'vincono', 'liberali', 'rutte', 'respinto', 'populismo'],
#  ['mimosa', 'semaforo', 'giallo', 'guardaroba', 'femminile'],
#  ['rudyguede', 'perugia', 'permesso', 'premio'],
#  ['hillaryclinton', 'candidarsi', 'sindaco', 'newyork'],
#  ['unaltra',
#   'serata',
#   'oblak',
#   'portiere',
#   'sloveno',
#   'dellatletico',
#   'madrid',
#   'migliori',
#   'ruolo'],
#  ['chiarimento', 'voucher', 'parla', 'aloisi', 'linkiesta'],
#  ['vittoria',
#   'rutte',
#   'olanda',
#   'scaccia',
#   'fantasma',
#   'infestava',
#   'riccardopennisi',
#   'marzo'],
#  ['chiede',
#   'luscita',
#   'dallue',
#   'tolleranza',
#   'migranti',
#   'forte',
#   'entrare',
#   'parlamento'],
#  ['colombia', 'santos', 'difende', 'accuse', 'corruzione', 'video'],
#  ['guerra', 'siria', 'limbo', 'rifugiati', 'gevisone'],
#  ['boxoffice', 'italia', 'labellaelabestia', 'debutta'],
#  ['minzolini',
#   'salvato',
#   'senato',
#   'maiali',
#   'politici',
#   'legge',
#   'uguale',
#   'tuttirivedi',
#   'diretta'],
#  ['letna', 'attivo', 'scatta', 'lallerta', 'rossa', 'spazi', 'aerei'],
#  ['commento', 'sappino', 'risposta', 'voucher', 'lavorare'],
#  ['migliore', 'investimento', 'obiettivi', 'linkiesta'],
#  ['mense',
#   'scolastiche',
#   'libera',
#   'pasto',
#   'garantito',
#   'diritto',
#   'allassistenza',
#   'inseg'],
#  ['paologentiloni',
#   'errore',
#   'dividere',
#   'litalia',
#   'referendum',
#   'cancellate',
#   'norme',
#   'voucher',
#   'appalti'],
#  ['orrore', 'parigi', 'sgozza', 'strada', 'padre', 'fratello'],
#  ['ligabue', 'sospeso'],
#  ['genio', 'kandinskij', 'marzo', 'luglio', 'mudecmi'],
#  ['quarti',
#   'finale',
#   'championsleague',
#   'juventusfc',
#   'fcbarcelona',
#   'juvebarcellona'],
#  ['nascite', 'causa', 'diseguaglianza', 'figli', 'ricchi', 'numero', 'pagina'],
#  ['furbetti', 'cartellino', 'affidano', 'allinformatica'],
#  ['loving', 'allamore', 'multirazziale'],
#  ['biogas',
#   'biometano',
#   'internazionale',
#   'valuter',
#   'benefici',
#   'economici',
#   'ambientali'],
#  ['idoneit', 'fisica', 'lavoratore', 'accertarla', 'visita', 'medica'],
#  ['licenziato', 'intervento', 'cuore', 'lazienda', 'marcia'],
#  ['settimanadelcaff',
#   'lafghanistan',
#   'rimpatri',
#   'richiedenti',
#   'asilo',
#   'dallue',
#   'cambio',
#   'aiuti',
#   'finanziari'],
#  ['voucher', 'servono', 'occasionale', 'emergere', 'evitare', 'propaganda'],
#  ['intesa', 'cariplo', 'vismara', 'povert', 'infantile'],
#  ['periodo', 'precari', 'pubblica', 'amministrazione', 'labour'],
#  ['israele', 'sfodera', 'arrow', 'intercettare', 'missili', 'siriani'],
#  ['andrea',
#   'pontremoli',
#   'dipende',
#   'italiani',
#   'campioni',
#   'mondiali',
#   'alibi'],
#  ['passivi', 'contenti', 'ragioni', 'scegliere', 'moneyfarmita'],
#  ['trumpmerkel', 'tensioni', 'cerca', 'disgelo'],
#  ['animalicomenoi', 'maiali', 'vivono', 'video'],
#  ['perdessi', 'brocca', 'aiutatemi', 'cercarla', 'cajetanusparvus'],
#  ['doping', 'olocausto', 'parole', 'diego', 'minuti'],
#  ['tentano', 'rapina', 'fumogeni', 'paura', 'piazza', 'marco'],
#  ['aleppo',
#   'bombardamento',
#   'moschea',
#   'morti',
#   'feriti',
#   'russia',
#   'attivisti'],
#  ['manca', 'populisti', 'sfondare', 'europa', 'maurizio', 'guandalini'],
#  ['trump', 'riceve', 'merkel', 'immigrazione', 'privilegio', 'diritto'],
#  ['confiscati', 'criminali'],
#  ['erdogan', 'depista', 'provoca', 'vietate', 'kippah'],
#  ['bimbi', 'mosul', 'scarpe', 'rotte', 'bisogna', 'andarb', 'gtgtgtgt'],
#  ['elezioni', 'salvare', 'democrazia'],
#  ['donna', 'offre', 'pranzare', 'regalo', 'nonna'],
#  ['ammazza', 'guerra', 'droga', 'sharia', 'perdukistan'],
#  ['marzo', 'dimenticher', 'giacomo', 'gatti'],
#  ['perch', 'pagare', 'parlamentari', 'voucher', 'estmieli'],
#  ['stepchild',
#   'famiglie',
#   'tradizionali',
#   'ununica',
#   'responsabilit',
#   'educativa',
#   'vannaio'],
#  ['lolanda', 'resta', 'liberale'],
#  ['nuova', 'forzaitalia', 'scommette'],
#  ['lautolettura', 'risparmiare', 'davvero'],
#  ['addio', 'jamescotton', 'armonica', 'storia', 'blues'],
#  ['teresaciabatti', 'leggere', 'parlo', 'statigenerali'],
#  ['mafia', 'sequestro', 'nebrodi', 'sicilia'],
#  ['commissione',
#   'sullintelligence',
#   'senato',
#   'esclude',
#   'trump',
#   'intercettato',
#   'dallamministrazione',
#   'obama'],
#  ['preoccupante',
#   'aumento',
#   'morbillo',
#   'ununica',
#   'soluzione',
#   'vaccini',
#   'ilpost'],
#  ['israele',
#   'intercetta',
#   'missile',
#   'lanciato',
#   'siria',
#   'azione',
#   'scudo',
#   'arrow'],
#  ['tifone',
#   'politico',
#   'coreadelsud',
#   'costretta',
#   'nuove',
#   'elezioni',
#   'limpeachment',
#   'presidente'],
#  ['ministri', 'decider', 'cancellazione', 'pagano', 'voucher', 'pensione'],
#  ['airfrance', 'domani', 'sciopero', 'leggi'],
#  ['spirit', 'lalbum', 'politico', 'depeche'],
#  ['sgozzatore', 'parigi', 'schedato', 'jihadista'],
#  ['tunisia', 'lattentato', 'museodelbardo', 'morirono', 'italiani'],
#  ['lattentatore',
#   'ucciso',
#   'allaeroporto',
#   'francia',
#   'iscritto',
#   'lista',
#   'potenziali',
#   'terroristi'],
#  ['tentato', 'attacco', 'allaeroporto', 'parigi', 'successo'],
#  ['salvini', 'vuole', 'soldi', 'terroni', 'salvare', 'frafloris'],
#  ['negoziazione', 'assistita', 'notaio', 'italia'],
#  ['proclamato',
#   'beato',
#   'josef',
#   'mayrnusser',
#   'padre',
#   'famiglia',
#   'disse',
#   'hitler',
#   'trasferimento',
#   'dachau'],
#  ['scoperta', 'italia', 'proteina', 'oppone', 'tumore'],
#  ['consigli', 'lettura', 'elisbook'],
#  ['problemi', 'whatsapp', 'aggiornamenti', 'corso'],
#  ['capitano', 'totti', 'bottura', 'testimonial', 'lotta', 'cancro', 'video'],
#  ['bernie',
#   'sanders',
#   'invita',
#   'giovani',
#   'progressisti',
#   'prendere',
#   'spunto',
#   'movimenti',
#   'diritti',
#   'civili',
#   'secolo'],
#  ['narciso',
#   'trump',
#   'schiacciato',
#   'trappola',
#   'massimo',
#   'paulryan',
#   'mikepence',
#   'lavocedinewyork'],
#  ['meteo', 'primavera', 'ombrello', 'occhiali', 'maggio', 'estate'],
#  ['rivoluzione',
#   'leonardo',
#   'arriva',
#   'profumo',
#   'confermati',
#   'descalzi',
#   'marcegaglia'],
#  ['warner',
#   'pensando',
#   'matrix',
#   'rumors',
#   'riportati',
#   'dallhollywood',
#   'reporter'],
#  ['decreto', 'errore', 'davidegiac'],
#  ['perch',
#   'europa',
#   'cresce',
#   'legemonia',
#   'destra',
#   'lultimo',
#   'libro',
#   'boltanski',
#   'esquerre',
#   'letto',
#   'giuliano',
#   'milani'],
#  ['milano', 'sequestro', 'droga', 'milione', 'arresto'],
#  ['bonus', 'gravidanza', 'ultime', 'novit'],
#  ['poste', 'farina', 'presidente', 'fante'],
#  ['crimea',
#   'russia',
#   'estratti',
#   'discorso',
#   'vladimir',
#   'putin',
#   'sullannessione',
#   'crimea',
#   'limesnerd'],
#  ['grillo', 'renzi', 'gestisce', 'nomine', 'grave', 'pericoloso'],
#  ['nordcorea', 'programma', 'nucleare', 'pyongyang', 'minaccia', 'imminente'],
#  ['assicurazione', 'temporanea', 'funziona', 'truffa'],
#  ['lolanda', 'resta', 'liberale'],
#  ['proposito', 'russia', 'crimea', 'ucraina', 'cantone'],
#  ['orlando', 'corteggia', 'milano', 'modello', 'centrosinistra', 'funziona'],
#  ['bollette', 'rischi', 'paghi', 'ritardo'],
#  ['poste', 'farina', 'presidente', 'fante'],
#  ['sorpresa', 'trattato', 'morbosit', 'voyeurismo'],
#  ['genoa', 'milan', 'leuropa', 'milangenoa'],
#  ['agnelli', 'deferiti', 'temiamo', 'dirigenza'],
#  ['arrendersi', 'partenza', 'fallire', 'centodiecimcu'],
#  ['mutui', 'sospese', 'famiglie'],
#  ['crozzamontezemolo', 'diventer', 'presidente', 'ryanair'],
#  ['festa'],
#  ['terremoto', 'scosse', 'notte', 'forte', 'maceratese'],
#  ['sanit', 'addio', 'ticket', 'funziona', 'esente'],
#  ['tragedia', 'viterbese', 'uccide', 'fidanzata', 'spara', 'porto', 'darmi'],
#  ['altissima', 'colonna', 'cenere', 'chiuso', 'laeroporto', 'catania'],
#  ['sevizie',
#   'stupri',
#   'migranti',
#   'lagghiacciante',
#   'racconto',
#   'vittime',
#   'ghanese',
#   'torturava'],
#  ['incisivo', 'cristo', 'michelangelo', 'dente'],
#  ['vasanello',
#   'giovane',
#   'silvia',
#   'tabacchi',
#   'uccisa',
#   'spiazzo',
#   'stradale',
#   'fidanzato',
#   'suicida'],
#  ['aeroportoorly',
#   'ucciso',
#   'lassalitore',
#   'rubato',
#   'pistola',
#   'poliziotto',
#   'operazione',
#   'corso'],
#  ['terrore', 'prime', 'immagini', 'dallaeroporto'],
#  ['immigrazione',
#   'terrorismo',
#   'marcominniti',
#   'sicurezza',
#   'libert',
#   'salpietroclara',
#   'lavocedinewyork'],
#  ['diktat',
#   'grillo',
#   'attivisti',
#   'genova',
#   'parma',
#   'pizzarotti',
#   'lavora',
#   'nuova'],
#  ['chuck', 'berry', 'morto', 'perso', 'gigante'],
#  ['ballandoconlestelle', 'guerra', 'albaparietti', 'giuria', 'ridicola'],
#  ['trump', 'mancata', 'stretta', 'merkerl', 'sentito', 'domanda'],
#  ['ragazzo',
#   'picchiato',
#   'bulli',
#   'mugnano',
#   'napoli',
#   'diventata',
#   'virale',
#   'centinaia',
#   'messaggi',
#   'affetto'],
#  ['attacchi', 'suicidi', 'uccidono', 'nordest', 'nigeria'],
#  ['poche', 'storie', 'renzi', 'sacrificare', 'voucher', 'servono', 'nuove'],
#  ['stipendi', 'crescono', 'passo', 'lumaca'],
#  ['terrorismo', 'esercitazioni', 'tamigi'],
#  ['tetto',
#   'esistenzialista',
#   'dellamante',
#   'scovato',
#   'vicina',
#   'riprende',
#   'gusto'],
#  ['rappresaglia',
#   'erdogan',
#   'deniz',
#   'yucel',
#   'terrorista',
#   'processare',
#   'denizyucel'],
#  ['salute', 'nuova', 'lista', 'gratuite'],
#  ['migrantisalvati', 'canale', 'sicilia'],
#  ['martin',
#   'schulz',
#   'eletto',
#   'presidente',
#   'partito',
#   'socialdemocratico',
#   'tedesco'],
#  ['allspeak', 'tecnologia', 'malati'],
#  ['gianluigi',
#   'buffon',
#   'giocatore',
#   'juventus',
#   'giocato',
#   'minuti',
#   'serie',
#   'storia'],
#  ['truffa', 'corre', 'social', 'succhiaeuro'],
#  ['erdogan', 'berlino', 'processare', 'reporter', 'tedesco'],
#  ['marco', 'biagi', 'erede', 'tiraboschi', 'applicate', 'autori', 'cinici'],
#  ['thailandia', 'fortuna', 'protezione', 'festival', 'tatuaggi', 'sacri'],
#  ['nuova', 'frontiera', 'gusto', 'plancton'],
#  ['passato',
#   'passa',
#   'tante',
#   'piccole',
#   'sedie',
#   'rosse',
#   'obrien',
#   'letto',
#   'goffredo'],
#  ['giulio', 'sapelli', 'impazzito', 'russia', 'putin'],
#  ['plebiscito', 'schulz', 'eletto', 'conquisteremo', 'cancelleria'],
#  ['destra',
#   'stravince',
#   'europa',
#   'italia',
#   'impossibile',
#   'analisi',
#   'paolonatalemi'],
#  ['boldrini',
#   'accoglie',
#   'studentessa',
#   'immigrata',
#   'negato',
#   'accesso',
#   'allaula',
#   'camera',
#   'video'],
#  ['signori',
#   'cenere',
#   'terza',
#   'opera',
#   'tersiterossi',
#   'narrativa',
#   'dinchiesta',
#   'globalizzazione'],
#  ['magistrissalvini', 'scintille'],
#  ['triste', 'festa', 'babbomat', 'spremuto', 'marzo', 'venezianimar'],
#  ['arriva', 'primavera', 'torna', 'pioggia'],
#  ['bonus', 'gravidanza', 'ultime', 'novit'],
#  ['erdogan', 'merkelpassato', 'segno'],
#  ['dimentica', 'lione', 'sassuolo', 'romasassuolo'],
#  ['laneurisma', 'dellaorta', 'addominale'],
#  ['gettano',
#   'rifiuti',
#   'strada',
#   'comiso',
#   'ripresi',
#   'messi',
#   'online',
#   'sindaco'],
#  ['crozzamontezemolo', 'diventer', 'presidente', 'ryanair'],
#  ['edicola', 'quotidiano', 'marzo', 'ardita', 'legge', 'salva', 'corrotti'],
#  ['lofficialasroma', 'rimonta', 'sassuolous', 'romasassuolo'],
#  ['occhi',
#   'cambiano',
#   'dellarcheologo',
#   'veltroniwalter',
#   'fruner',
#   'iicnewyork',
#   'lavocedinewyork'],
#  ['allarme',
#   'bomba',
#   'casabianca',
#   'fermata',
#   'persona',
#   'sostiene',
#   'ordigno',
#   'bordo',
#   'dellautomobile'],
#  ['corea', 'testato', 'motore', 'missili'],
#  ['allarme', 'bomba', 'bianca', 'fermato'],
#  ['allarme', 'bomba', 'bianca', 'fermato'],
#  ['crollo',
#   'nascite',
#   'aumento',
#   'dellet',
#   'media',
#   'crescita',
#   'diseguaglianze',
#   'nesso',
#   'allarmante',
#   'ignorato'],
#  ['arriva', 'primavera', 'torna', 'pioggia'],
#  ['prime', 'pagine'],
#  ['lingegnerechef', 'cucina', 'stampante'],
#  ['stragi',
#   'naziste',
#   'italia',
#   'condanna',
#   'berlino',
#   'lascia',
#   'impuniti',
#   'frustrazione',
#   'problema',
#   'politico'],
#  ['dissesto', 'idrogeologico', 'sviluppo', 'acque', 'ditalia', 'video'],
#  ['profumo',
#   'approda',
#   'finmeccanica',
#   'finire',
#   'lopera',
#   'moretti',
#   'libere',
#   'scheletri',
#   'affrontare'],
#  ['motogp', 'vinales', 'forma', 'mondiale', 'rossiampco', 'inseguono'],
#  ['voucher', 'irriducibili', 'giocano', 'perdere'],
#  ['buona', 'domenica', 'buonalettura', 'geopolitica', 'settimana'],
#  ['passeggio',
#   'siberia',
#   'baikal',
#   'turisti',
#   'inquinamento',
#   'reportage',
#   'marina',
#   'forti'],
#  ['soleore',
#   'casta',
#   'confindustria',
#   'media',
#   'preferiscono',
#   'sparare',
#   'camusso',
#   'turno',
#   'giuseppecaldaro'],
#  ['paesi', 'felici', 'paesifelici', 'felicit', 'happyness'],
#  ['perch', 'deciso', 'madre', 'surrogata'],
#  ['brexit', 'comincia', 'marzo'],
#  ['brexit', 'marzo', 'theresa', 'attiver', 'larticolo', 'luscita', 'dallue'],
#  ['brexit', 'marzo', 'partir', 'liter', 'luscita', 'bretagna'],
#  ['allergie',
#   'primavera',
#   'lesperto',
#   'domani',
#   'diretta',
#   'adnkronoslive',
#   'domanda'],
#  ['rientrato', 'lallerta', 'bomba', 'tribunale', 'parigi'],
#  ['lamerica', 'preoccupiamo', 'hacker', 'russi', 'linkiesta'],
#  ['documentari',
#   'internazionale',
#   'vicenza',
#   'castelfranco',
#   'emilia',
#   'brescia',
#   'gorizia',
#   'bologna',
#   'calendario'],
#  ['soleore', 'studiano', 'finanziamenti', 'milionari', 'mudec', 'giustiziami'],
#  ['piccolo', 'bradipo', 'mamma', 'wendy', 'video'],
#  ['geografia',
#   'dellitalia',
#   'stelle',
#   'grillini',
#   'conquista',
#   'ilbrontolo',
#   'mmarcosarti'],
#  ['accordo',
#   'ueturchia',
#   'migranti',
#   'fallimento',
#   'piano',
#   'diritti',
#   'umani'],
#  ['perch', 'russia', 'libia', 'interessa'],
#  ['ricordate'],
#  ['desiderio', 'ossessione', 'giocatore', 'teatrobellini', 'napoli'],
#  ['selfie', 'sorrisi', 'senantoniorazzi', 'visita', 'assad'],
#  ['cartina', 'geografica', 'corretta'],
#  ['brexit', 'lasciarsi'],
#  ['bimbo',
#   'autistico',
#   'rifiutato',
#   'scuole',
#   'lanciano',
#   'mamma',
#   'rivolge',
#   'sindaco'],
#  ['meningite', 'donna', 'muore', 'spezia'],
#  ['lunione', 'consumatori', 'messo', 'punto', 'guida', 'multe'],
#  ['piazza', 'affari', 'declino', 'servito', 'moneyfarmita'],
#  ['attentato',
#   'baghdad',
#   'esplode',
#   'unautobomba',
#   'morti',
#   'feriti',
#   'gtgthttpstcoidweqlltlt'],
#  ['torna', 'legale', 'lancette'],
#  ['brexit', 'linghilterra', 'deciso', 'marzo', 'alliter', 'uscire'],
#  ['maestri',
#   'italy',
#   'vicenza',
#   'dedica',
#   'mostra',
#   'raccontiamo',
#   'numero',
#   'pagina'],
#  ['resistiamo', 'mosul', 'lisis', 'diffonde', 'video', 'battaglia'],
#  ['sindaca', 'raggi', 'riapre', 'edicolafiore', 'permessi', 'messivideo'],
#  ['bobogiac', 'beppegrillo', 'beppe', 'marchese'],
#  ['trump',
#   'figlio',
#   'donald',
#   'trump',
#   'moglie',
#   'yunaska',
#   'aspettano',
#   'bambino'],
#  ['multe', 'sapere'],
#  ['video', 'dellaggressione', 'allaeroporto', 'parigi'],
#  ['copertine', 'semplicissime', 'dischi', 'famosi', 'ilpost'],
#  ['salute', 'nuova', 'lista', 'gratuite'],
#  ['martin',
#   'schulz',
#   'risveglia',
#   'sinistra',
#   'tedesca',
#   'sfida',
#   'angela',
#   'merkel'],
#  ['nuova', 'banconota'],
#  ['edicola',
#   'quotidiano',
#   'marzo',
#   'giglio',
#   'magico',
#   'prende',
#   'contributi',
#   'assunti',
#   'mette'],
#  ['problema', 'parliamone', 'sabato', 'resta', 'autori', 'sanno', 'leggere'],
#  ['arriva', 'primavera', 'torna', 'pioggia'],
#  ['bonus', 'gravidanza', 'ultime', 'novit'],
#  ['lascio',
#   'politica',
#   'pensione',
#   'africa',
#   'ultime',
#   'parole',
#   'famose',
#   'irrottamabili'],
#  ['alitalia'],
#  ['dallolanda', 'scozia', 'leuropa', 'stufata', 'populismi', 'flaviaperina'],
#  ['stipendio',
#   'figli',
#   'fantastico',
#   'problema',
#   'denatalit',
#   'serve',
#   'bazooka'],
#  ['numero', 'pagina', 'edicola', 'digitale', 'venerd'],
#  ['responsabilit', 'dominio', 'ruolo', 'maschere', 'grillo', 'alternate'],
#  ['rischi', 'mestiere', 'peanuts'],
#  ['prepara',
#   'sabato',
#   'violenza',
#   'manifestazioni',
#   'sitin',
#   'centro',
#   'blindato',
#   'black'],
#  ['lazio', 'andamento', 'lento', 'pagelliadi', 'franesco', 'troncarelli'],
#  ['islam', 'religione', 'entro'],
#  ['lessere',
#   'genitori',
#   'diventata',
#   'rarit',
#   'perch',
#   'sostiene',
#   'famiglia',
#   'letimencarini'],
#  ['perch', 'lausterit', 'colpisce', 'donne'],
#  ['prodi', 'doppia', 'circolazione', 'eurolira', 'farsi', 'curare'],
#  ['irlanda', 'morto', 'martin', 'mcguinness', 'dellira', 'londra'],
#  ['francesco', 'confessionale', 'tintoria', 'smacchiare', 'peccati'],
#  ['annamagnani', 'vinceva', 'loscar'],
#  ['ciotti',
#   'annunciato',
#   'conceder',
#   'legge',
#   'bacchelli',
#   'giornalista',
#   'antimafia',
#   'riccardo',
#   'orioles'],
#  ['appoggia', 'emmanuel', 'macron', 'ambiguit', 'martin', 'schulz'],
#  ['dirigenti', 'pubblici', 'mariuoli', 'prescindere', 'linkiesta'],
#  ['svelato',
#   'segreto',
#   'corse',
#   'spermatozoi',
#   'physrevlett',
#   'yorkuniversity',
#   'bcupressoffice',
#   'uniofoxford'],
#  ['juvemilan', 'minacciato', 'larbitro', 'massa'],
#  ['francesco', 'giovani', 'fatevi', 'fuorviare', 'realityshow'],
#  ['scienziati',
#   'barrieracorallina',
#   'australiana',
#   'morta',
#   'allarme',
#   'ambiente'],
#  ['primi', 'beppe', 'grillo'],
#  ['milione', 'famiglie', 'italia', 'istat'],
#  ['renzi', 'mamma', 'massimofamularo'],
#  ['agenzie', 'stampa', 'fermano', 'protesta'],
#  ['innovazione',
#   'digitale',
#   'investimenti',
#   'mancati',
#   'perch',
#   'ultimi',
#   'europa'],
#  ['stragi', 'bruxelles', 'ricordo', 'video'],
#  ['marzo', 'diretta', 'peter', 'gomez'],
#  ['ritira', 'lotti', 'antibiotico', 'antineoplastico'],
#  ['dellinterno', 'francese', 'guaio', 'simile', 'fillon'],
#  ['guardate', 'successo'],
#  ['eataly', 'primavera', 'tiramisuday', 'uniniziativa', 'gigipadovani'],
#  ['figli', 'costa', 'risparmiare', 'investire'],
#  ['complessa', 'rischia', 'frrrrrpacifico'],
#  ['scrittore', 'diverte', 'ilpost'],
#  ['genitori',
#   'interrotti',
#   'figli',
#   'vengono',
#   'strappati',
#   'madre',
#   'padre',
#   'ingiustamente'],
#  ['sindacati', 'convocati', 'ministero', 'domani'],
#  ['trovata', 'scuola', 'bimbo', 'autistico', 'rifiutato', 'chietino'],
#  ['litalia',
#   'specchio',
#   'sicilia',
#   'intervista',
#   'letizia',
#   'battaglia',
#   'franco',
#   'maresco',
#   'grrrizzo'],
#  ['monica', 'bellucci', 'madrina', 'festival', 'cannes'],
#  ['scopri', 'felice'],
#  ['perso',
#   'incontro',
#   'rivivere',
#   'festival',
#   'limesonline',
#   'canale',
#   'youtube'],
#  ['studio', 'barrieracorallina', 'morta'],
#  ['morto',
#   'alfredo',
#   'reichlin',
#   'storico',
#   'rispettato',
#   'dirigente',
#   'giornalista',
#   'sinistra',
#   'italiana'],
#  ['morto', 'alfredo', 'reichlin'],
#  ['addio',
#   'alfredo',
#   'reichlin',
#   'ultimi',
#   'grandi',
#   'dirigenti',
#   'comunisti',
#   'alfredoreichlin'],
#  ['svegliarsi',
#   'pezzi',
#   'scelti',
#   'telegram',
#   'risolleviamo',
#   'giornata',
#   'gratis'],
#  ['francia',
#   'inizia',
#   'corsa',
#   'alleliseo',
#   'dibattito',
#   'macron',
#   'convincente'],
#  ['nucleari', 'tolto', 'segreto', 'esperimenti', 'video'],
#  ['francia', 'dibattito', 'eliseo', 'macron'],
#  ['lista',
#   'donne',
#   'dellest',
#   'chiude',
#   'parliamone',
#   'sabato',
#   'servizio',
#   'pubblico'],
#  ['presidenziali',
#   'francia',
#   'dibattito',
#   'televisivo',
#   'brilla',
#   'lastro',
#   'macron',
#   'convinto',
#   'spettatori'],
#  ['celebrit', 'lavori', 'normali', 'video'],
#  ['mobilitiamoroma',
#   'ripartire',
#   'capitale',
#   'metilparaben',
#   'invita',
#   'cambiare',
#   'vento',
#   'trasporti',
#   'romani'],
#  ['scena', 'ballo', 'bella', 'gosling', 'stone'],
#  ['andato', 'fuoco', 'ciampino', 'guarda'],
#  ['morto',
#   'alfredo',
#   'reichlin',
#   'partigiano',
#   'storico',
#   'dirigente',
#   'direttore',
#   'lunit'],
#  ['morto',
#   'alfredo',
#   'reichlin',
#   'addio',
#   'storico',
#   'dirigente',
#   'lasciamo',
#   'sinistra'],
#  ['perquisizioni', 'leader', 'movimento', 'forconi', 'sequestrati'],
#  ['sovranista', 'destra', 'xenofoba', 'litiga', 'insegue', 'trump', 'compete'],
#  ['rifugiati', 'vivono', 'tragedia', 'seconda', 'guerra', 'mondiale'],
#  ['giornatamondialedellacqua',
#   'storia',
#   'contaminazione',
#   'massa',
#   'veneto',
#   'davidegangale'],
#  ['bagnasco', 'attenzione', 'segnali', 'secessione', 'facili', 'populismi'],
#  ['stress', 'stanchezza', 'primavera', 'agguato', 'difendersi'],
#  ['migranti', 'ombre', 'fondi'],
#  ['migranti', 'pontifexit', 'tragedia', 'seconda', 'guerra', 'mondiale'],
#  ['piano', 'erdogan', 'litigare', 'leuropa', 'musulmano'],
#  ['lifemovie',
#   'lanteprima',
#   'collegamento',
#   'lastronauta',
#   'paolo',
#   'nespoli',
#   'video',
#   'biagiu'],
#  ['calano', 'vittime', 'tumori'],
#  ['studente',
#   'universitario',
#   'italiano',
#   'morto',
#   'appartamento',
#   'valencia',
#   'spagna'],
#  ['museo',
#   'culture',
#   'milano',
#   'gestito',
#   'cultura',
#   'deragliato',
#   'barbie',
#   'andreadusio'],
#  ['texas',
#   'approva',
#   'disegno',
#   'legge',
#   'autorizza',
#   'medici',
#   'mentire',
#   'donne',
#   'incinte'],
#  ['spazio',
#   'horror',
#   'lifemovie',
#   'astronauti',
#   'tornano',
#   'protagonisti',
#   'schermo',
#   'ferroneenrico'],
#  ['progetti', 'testimonidilibert', 'legacooplombard'],
#  ['crimea',
#   'cambiato',
#   'marzo',
#   'risultati',
#   'referendum',
#   'tensione',
#   'resta'],
#  ['feriti', 'lattentatore', 'cercato', 'entrare', 'westminster', 'londra'],
#  ['armato',
#   'coltello',
#   'irruzione',
#   'parlamento',
#   'londra',
#   'accoltella',
#   'poliziotto',
#   'viene',
#   'ucciso',
#   'westminster'],
#  ['londra',
#   'morta',
#   'donna',
#   'gravi',
#   'ferite',
#   'riportate',
#   'ponte',
#   'westminster',
#   'confermarlo',
#   'medico',
#   'stthomas'],
#  ['almeno', 'civili', 'uccisi', 'bombardamento', 'americano', 'siria'],
#  ['immagine', 'realizzata', 'bloomberg', 'mostra', 'svolto', 'lattacco'],
#  ['polizia',
#   'scientifica',
#   'esaminando',
#   'lauto',
#   'schiantata',
#   'cancellata',
#   'westminster'],
#  ['londra',
#   'attacco',
#   'parlamento',
#   'westminster',
#   'passanti',
#   'spari',
#   'videoltltlthttpstcoclsxbuzgs'],
#  ['attaccolondra', 'sostenitori', 'festeggiano', 'sangue', 'sangue'],
#  ['follia', 'taranto', 'squadra', 'aggredita', 'incappucciati'],
#  ['starbucks', 'italia', 'benedizione', 'parola', 'piccolo', 'produttore'],
#  ['disponibile',
#   'lagenda',
#   'forum',
#   'portualit',
#   'logistica',
#   'mercoled',
#   'livorno',
#   'mitgov',
#   'ramspa'],
#  ['terrorista',
#   'izzadeen',
#   'islamista',
#   'radicale',
#   'arrestato',
#   'londra',
#   'abuizzadeen',
#   'westminster'],
#  ['tablet', 'perch', 'qaida', 'lavora', 'esplosivi', 'batterie'],
#  ['qaida', 'lavora', 'esplosivo', 'tablet'],
#  ['sciopero', 'confermato', 'domani', 'bianche'],
#  ['sesso', 'minori', 'nicola', 'sindaco', 'indagine', 'corso'],
#  ['poste', 'poesia', 'giornata', 'mondiale'],
#  ['killer', 'londra', 'izzadeen', 'errore', 'perch', 'prigione'],
#  ['lufficio',
#   'presidenza',
#   'camera',
#   'approvato',
# ...
#  ['scuola', 'marocco'],
#  ['crisi', 'infinita', 'partito', 'romano', 'mafiacapitale'],
#  ['chailly', 'toscanini', 'cambiato', 'mestiere', 'direttore', 'dorchestra'],
#  ['enricoletta', 'pogba', 'dance', 'convegno', 'europa'],
#  ['deluca', 'chiama', 'chiattona', 'consigliera', 'grillo'],
#  ['consigli', 'superare', 'blocco', 'scrittore', 'sopravvalutarlo'],
#  ['marco',
#   'bellocchio',
#   'cinema',
#   'dautore',
#   'italiano',
#   'finito',
#   'quellitalia'],
#  ['domenica', 'circolare'],
#  ['iltempodelcoraggio',
#   'martafana',
#   'dobbiamo',
#   'tornare',
#   'conflitti',
#   'creano',
#   'uscire',
#   'politica'],
#  ['pellegrina', 'pellegrini', 'nellampabbraccio', 'ultimi', 'francesco'],
#  ['lancette', 'perch', 'cambia', 'lorario'],
#  ['elettricit', 'dritte', 'scegliere', 'lofferta', 'migliore'],
#  ['barbarie',
#   'ferma',
#   'decreti',
#   'sicurezza',
#   'nfratoianni',
#   'parla',
#   'politica',
#   'dellaccoglienza',
#   'iltempodelcoraggio'],
#  ['merkel',
#   'produce',
#   'renzi',
#   'produce',
#   'salvini',
#   'endtina',
#   'iltempodelcoraggio'],
#  ['italiani', 'arrabbiati', 'vuole', 'vender', 'prodotti', 'rispettarli'],
#  ['whatsapp', 'video', 'scatena', 'panico'],
#  ['edicola',
#   'quotidiano',
#   'marzo',
#   'leader',
#   'firmano',
#   'dichiarazione',
#   'unione'],
#  ['protegger',
#   'patrimonio',
#   'culturale',
#   'paesi',
#   'conflitto',
#   'amendolaenzo',
#   'italyunny',
#   'carabinieri'],
#  ['acmilan', 'closing', 'avvicina', 'versati'],
#  ['superpillola', 'antiet', 'scoperta', 'chiave', 'riparare', 'leggi'],
#  ['chiama', 'chiattona', 'consigliera', 'grillo'],
#  ['fantasticando', 'pesci'],
#  ['trattatidiroma',
#   'gentiloni',
#   'raggi',
#   'accolgono',
#   'leader',
#   'europei',
#   'campidoglio',
#   'europa'],
#  ['sconfitta', 'trump'],
#  ['dannunzio', 'finisce', 'cabaret'],
#  ['serrande',
#   'abbassate',
#   'centro',
#   'deserto',
#   'capitale',
#   'blindata',
#   'scena',
#   'paura',
#   'black',
#   'trattatiroma'],
#  ['earth',
#   'unora',
#   'clima',
#   'cambia',
#   'pietro',
#   'torre',
#   'eiffel',
#   'monumenti'],
#  ['francesco', 'milano', 'prime', 'immagini'],
#  ['liampayne', 'cantante', 'onedirection'],
#  ['fatti', 'notizie', 'false', 'ilpost'],
#  ['siria',
#   'lisis',
#   'pronto',
#   'proclamare',
#   'califfato',
#   'filippine',
#   'gtgtgt'],
#  ['ricconi', 'calcio', 'europeo', 'soldi'],
#  ['correre', 'formula', 'campionato', 'elettriche'],
#  ['virginiaraggi', 'storico', 'cittadini', 'messi', 'centro'],
#  ['alexei',
#   'navalny',
#   'avversario',
#   'politico',
#   'presidente',
#   'russo',
#   'vladimir',
#   'putin',
#   'arrestato'],
#  ['enrico',
#   'letta',
#   'primarie',
#   'voter',
#   'andrea',
#   'orlando',
#   'lunico',
#   'vuole',
#   'unire'],
#  ['philippe', 'daverio', 'leuropa', 'crisi', 'colpa', 'cavolo'],
#  ['serra', 'ranghi', 'supercalcolo', 'automotive', 'industria'],
#  ['flippy', 'robot', 'cucina', 'hamburger', 'video'],
#  ['cause',
#   'tumori',
#   'mutazioni',
#   'casuali',
#   'dirlo',
#   'ricercatori',
#   'statunitensi'],
#  ['pisapia', 'polemico', 'stampella', 'renzi', 'gtgtgt'],
#  ['imbecille', 'pensieri', 'segreti', 'filcusum'],
#  ['russia',
#   'proteste',
#   'arrestato',
#   'leader',
#   'opposizione',
#   'navalny',
#   'prelevate'],
#  ['leader',
#   'dellopposizione',
#   'alexei',
#   'navalny',
#   'arrestato',
#   'manifestazione',
#   'corruzione',
#   'mosca'],
#  ['stasera'],
#  ['martin', 'schulz', 'messaggio', 'antisessista', 'stiro', 'panni', 'gtgtgt'],
#  ['lealt',
#   'valori',
#   'ideali',
#   'comuni',
#   'lezione',
#   'dellebraismo',
#   'societ',
#   'liquide',
#   'stefano',
#   'jesurum'],
#  ['cedolino',
#   'partire',
#   'lordi',
#   'rimborsi',
#   'forfettari',
#   'fondi',
#   'restituiti',
#   'buste'],
#  ['versare', 'goccia', 'video'],
#  ['sostituta', 'licenziati', 'storia', 'incinta'],
#  ['cambiata', 'legale'],
#  ['camus', 'felicit', 'vissuta', 'colpa'],
#  ['motogp',
#   'losail',
#   'vinales',
#   'vince',
#   'duello',
#   'dovizioso',
#   'valentino',
#   'rossi',
#   'conquista',
#   'podio'],
#  ['whatsapp', 'nuova', 'funzione'],
#  ['ipotesi', 'assurde', 'gioconda', 'sorriso', 'scienza'],
#  ['edicola',
#   'quotidiano',
#   'marzo',
#   'scandalo',
#   'linterdetto',
#   'minzolini',
#   'sconta',
#   'senato'],
#  ['ardeatine', 'raggi', 'banalit', 'fcammalleri', 'lavocedinewyork'],
#  ['lamore',
#   'paola',
#   'mastrocola',
#   'emozioni',
#   'divini',
#   'elisabetta',
#   'dominis',
#   'libri'],
#  ['australia', 'hamilton'],
#  ['domenica', 'circolare'],
#  ['scoprirlo'],
#  ['torna', 'legale', 'consigli', 'pediatra'],
#  ['treno', 'pagare', 'biglietti'],
#  ['scossa', 'termica', 'arriva'],
#  ['mutuo', 'requisiti', 'agevolazioni', 'fiscali'],
#  ['terrorismo', 'continuer', 'colpire', 'vincendo'],
#  ['bella', 'renziana', 'manfuso', 'matteorenzi'],
#  ['sbloccata', 'cessione', 'milan'],
#  ['segnali', 'stradali', 'collezione'],
#  ['titoli', 'quotidiani'],
#  ['famiglie', 'italiane', 'rosso', 'indebitate'],
#  ['travolge', 'operai', 'morti'],
#  ['lazio', 'lotito', 'mafie', 'maglie', 'presto', 'libera', 'gtgtgt'],
#  ['pasblocco', 'turnover', 'comuni'],
#  ['lelemora', 'corona', 'bipolare', 'malato', 'soldi', 'curato', 'video'],
#  ['marzo',
#   'romania',
#   'festeggia',
#   'lunione',
#   'bessarabia',
#   'occhio',
#   'moldova',
#   'putin',
#   'mirkomussetti'],
#  ['fratellini', 'trovati', 'morti', 'trento', 'suicidato'],
#  ['uffizi', 'torna', 'splendere', 'ladorazione', 'leonardo', 'gtgtgt'],
#  ['insorsi',
#   'cooperazione',
#   'commercio',
#   'meridionale',
#   'ostacolati',
#   'crisi',
#   'india',
#   'pakistan'],
#  ['morire', 'amazon', 'lecommerce', 'sparire', 'negozi'],
#  ['londra', 'terrorista', 'khalid', 'masood', 'indagato', 'terrorismo'],
#  ['lealt',
#   'valori',
#   'ideali',
#   'comuni',
#   'lezione',
#   'dellebraismo',
#   'societ',
#   'liquide'],
#  ['manovra',
#   'miliardo',
#   'misure',
#   'proterremoto',
#   'possibile',
#   'usare',
#   'manovrina',
#   'spese',
#   'sisma',
#   'patto'],
#  ['votata', 'allunanimit', 'decadenza', 'organi', 'serie'],
#  ['linfarto', 'massimo', 'lopez', 'posta', 'video', 'facebook'],
#  ['trento',
#   'bambini',
#   'trovati',
#   'morti',
#   'madre',
#   'corpo',
#   'padre',
#   'scarpata'],
#  ['notap', 'gasdotto', 'salento', 'libera'],
#  ['pillole', 'dellamore', 'dilaga'],
#  ['ivankatrump', 'vertice', 'donne'],
#  ['maltrattava',
#   'bambini',
#   'arrestata',
#   'maestra',
#   'scuola',
#   'dellinfanzia',
#   'scarabocchio',
#   'fiumicino'],
#  ['viaggio', 'india', 'belle'],
#  ['malmo',
#   'assalti',
#   'granate',
#   'arrivano',
#   'dallexjugoslavia',
#   'antoniotalia',
#   'oltreconfine'],
#  ['elucid',
#   'armand',
#   'hammer',
#   'favorite',
#   'appena',
#   'pubblicato',
#   'valleyofgrace',
#   'elucidwho',
#   'rapper'],
#  ['alitalia', 'poletti', 'situazione', 'difficile'],
#  ['fondi', 'federali', 'ospitano', 'clandestini'],
#  ['scene', 'crisi', 'greca', 'racconto', 'fotografico', 'atene'],
#  ['poletti',
#   'opportunit',
#   'giocando',
#   'calcetto',
#   'spedire',
#   'curricula',
#   'polemiche',
#   'frase'],
#  ['panino', 'scuola', 'ministero'],
#  ['nuova',
#   'bufera',
#   'poletti',
#   'calcetto',
#   'curriculum',
#   'insorgono',
#   'dubbi'],
#  ['poletti', 'opportunit', 'calcetto', 'curricula'],
#  ['colombia', 'andare', 'ubriachi', 'licenziati'],
#  ['cinema',
#   'david',
#   'trionfa',
#   'paolovirz',
#   'lapazzagioia',
#   'stefanoaccorsi',
#   'miglior',
#   'attore',
#   'protagonista'],
#  ['legale', 'denuncia', 'parcometri', 'aggiornati'],
#  ['ladri', 'regole', 'furti'],
#  ['problema',
#   'sinistra',
#   'liberarsi',
#   'renzi',
#   'ritrovare',
#   'valori',
#   'socialisti',
#   'pietro',
#   'folena'],
#  ['terremoto', 'scossa', 'reatino'],
#  ['corea', 'procura', 'vuole', 'arresto'],
#  ['sostituta', 'licenziati', 'storia', 'incinta'],
#  ['sanit', 'addio', 'ticket', 'funziona', 'esente'],
#  ['arrivata', 'legale', 'occhio', 'alleffetto'],
#  ['radiografia',
#   'degrado',
#   'sfregio',
#   'allarte',
#   'pantheon',
#   'ucciso',
#   'branco',
#   'ragazza',
#   'aspettiamo',
#   'edicola',
#   'buongiorno'],
#  ['ribalta', 'anzio', 'muore', 'ragazzo', 'feriti'],
#  ['parquet', 'trieste', 'spunta', 'anello', 'sposarmi', 'basket', 'guarda'],
#  ['cercare',
#   'lalleanza',
#   'errore',
#   'capitale',
#   'articolouno',
#   'leditoriale',
#   'peppino',
#   'caldarola'],
#  ['lamerica', 'trump', 'pilota', 'leuropa', 'tenerne', 'conto'],
#  ['caldo', 'anomalo', 'maltempo', 'agguato'],
#  ['fatta', 'famiglia'],
#  ['kaurismaki', 'governi', 'europei', 'accoglienza', 'teresa', 'marchesi'],
#  ['banda', 'progettava', 'furto', 'salma', 'ferrari'],
#  ['mosul', 'dramma', 'imperversano', 'combattimenti', 'vecchia'],
#  ['libera', 'maglia', 'dellofficialsslazio', 'sabato', 'prossimo', 'sassuolo'],
#  ['massacrato', 'branco', 'alatri', 'fermi', 'bevanda'],
#  ['patto',
#   'macron',
#   'schulz',
#   'renzi',
#   'cambiare',
#   'leuropa',
#   'battere',
#   'populisti',
#   'linkiesta'],
#  ['banco', 'santander', 'foglio', 'dallitalia'],
#  ['studiare', 'linguaitaliana', 'stile', 'incontra', 'dieselhttpowlyhtpajzyw'],
#  ['genova',
#   'cassimatis',
#   'annuncia',
#   'ricorso',
#   'voglio',
#   'scuse',
#   'beppegrillo'],
#  ['genova',
#   'cassimatis',
#   'ricorso',
#   'querela',
#   'grillo',
#   'battista',
#   'conferenza',
#   'intimidazioni',
#   'minacce'],
#  ['poletti', 'giovani', 'darsi', 'calcio', 'linkiesta'],
#  ['sperona',
#   'lauto',
#   'moglie',
#   'accoltella',
#   'donna',
#   'episodio',
#   'vercellese'],
#  ['listruttore',
#   'deride',
#   'perch',
#   'autistico',
#   'studia',
#   'legge',
#   'causa',
#   'palestra',
#   'vincendola'],
#  ['linvasione',
#   'rifugiati',
#   'italia',
#   'numeri',
#   'alessandrolanni',
#   'cartadiroma'],
#  ['francia', 'record', 'sella', 'video'],
#  ['studente', 'morto', 'valencia', 'eseguita', 'nuova', 'autopsia'],
#  ['interviste',
#   'pagamento',
#   'confermate',
#   'condanne',
#   'capigruppo',
#   'regione',
#   'emiliaromagna'],
#  ['unici',
#   'incappucciati',
#   'ulivi',
#   'togliendo',
#   'radici',
#   'resta',
#   'presidio',
#   'tranquillo',
#   'pacifico',
#   'notap',
#   'salento',
#   'puglia'],
#  ['scrivo', 'foglietto', 'tappezziere', 'perdo', 'foglietto'],
#  ['jamie', 'wilson', 'musicista', 'transgender', 'abbatte', 'stereotipi'],
#  ['amazon', 'monopolisti', 'parola', 'antitrust'],
#  ['turchia', 'referendum', 'sfida', 'sultano', 'leggi', 'magazine', 'erdogan'],
#  ['scozia', 'parlamento', 'referendum', 'indipendenza'],
#  ['bacino',
#   'tidal',
#   'washington',
#   'festival',
#   'fioritura',
#   'ciliegi',
#   'reuterscontrasto'],
#  ['camus', 'felicit', 'vissuta', 'colpa'],
#  ['litalia', 'garantisca', 'laccesso', 'aborti', 'legali', 'aborto', 'legge'],
#  ['italiani', 'popolo', 'santi', 'navigatori', 'migranti'],
#  ['bisarca',
#   'tampona',
#   'pullman',
#   'feriti',
#   'raccordo',
#   'bolognese',
#   'bologna',
#   'incidente'],
#  ['olandaitalia', 'seguire', 'sfida'],
#  ['autobiografia', 'letteraria', 'rivoluzione', 'russa'],
#  ['whatsapp', 'messaggi', 'cancellabili', 'entro', 'minuti'],
#  ['cattive', 'buone'],
#  ['terremoto',
#   'lelenco',
#   'banche',
#   'erogano',
#   'finanziamenti',
#   'agevolati',
#   'leggi'],
#  ['trump', 'smantellando', 'leredita', 'ambientalista', 'obama'],
#  ['patente', 'infrazioni', 'costano', 'punti'],
#  ['sapevate', 'tomba', 'trova', 'giappone'],
#  ['sbarca', 'centro'],
#  ['indagata',
#   'penelope',
#   'fillon',
#   'lepen',
#   'torna',
#   'testa',
#   'sondaggi',
#   'valls',
#   'sostiene',
#   'macron',
#   'francia'],
#  ['leuropa', 'periferica', 'periferie', 'maurizio', 'guandalini'],
#  ['segnale', 'crescita', 'populismi', 'claudiogiua'],
#  ['lavoceny',
#   'commento',
#   'daviddidonatello',
#   'componente',
#   'variegata',
#   'giuria'],
#  ['compleanno', 'monicafrassoni'],
#  ['sbarca', 'centro'],
#  ['gasdotto', 'salento', 'libera'],
#  ['pillole', 'dellamore', 'dilaga'],
#  ['curare', 'cancro', 'farmaci', 'bugie', 'libro'],
#  ['david', 'donatello', 'vincitori', 'david'],
#  ['patto',
#   'macron',
#   'schulz',
#   'renzi',
#   'cambiare',
#   'leuropa',
#   'battere',
#   'populisti',
#   'linkiesta'],
#  ['ministra', 'marianna', 'madia', 'dottorato', 'parole', 'copiate'],
#  ['kento', 'stasera', 'suoner', 'lavoceny', 'intervistato', 'hiphop'],
#  ['italiana', 'ricchi', 'spaventa', 'berlino'],
#  ['caccia', 'pianeta'],
#  ['formula', 'regole', 'ferrari', 'pronta'],
#  ['germania',
#   'vogliono',
#   'trasformare',
#   'vecchia',
#   'miniera',
#   'unenorme',
#   'batteria',
#   'ilpost'],
#  ['addio',
#   'ahmed',
#   'kathrada',
#   'veterano',
#   'lotta',
#   'allapartheid',
#   'razzista',
#   'sudafrica',
#   'gtgtgt'],
#  ['calcetto', 'curricula', 'bufera', 'poletti', 'matteosalvinimi', 'dimetta'],
#  ['italiani', 'popolo', 'santi', 'navigatori', 'migranti', 'linkiesta'],
#  ['pazza',
#   'gioia',
#   'valeria',
#   'bruni',
#   'tedeschi',
#   'david',
#   'ringrazio',
#   'psicanalista',
#   'lapazzagioia',
#   'gtgtgt'],
#  ['milionario', 'nullatenente', 'milano', 'finanza', 'confisca'],
#  ['sinistra', 'sguardo', 'disturba', 'serve', 'concentrazione'],
#  ['libera',
#   'definitivo',
#   'camera',
#   'deputati',
#   'legge',
#   'proteggere',
#   'iminori',
#   'stranieri',
#   'accompagnati'],
#  ['ultimora',
#   'barrow',
#   'consegnato',
#   'eucopresident',
#   'lettera',
#   'theresamay',
#   'invoca',
#   'trattato',
#   'lisbona',
#   'brexit',
#   'iniziato'],
#  ['brexit', 'tappe', 'divorzio'],
#  ['scali',
#   'nuova',
#   'scenari',
#   'mostra',
#   'milano',
#   'fuorisalone',
#   'scalimilano',
#   'comunemi'],
#  ['carminatiio',
#   'vecchio',
#   'fascista',
#   'contento',
#   'esserlo',
#   'mistero',
#   'ditalia',
#   'spicca'],
#  ['innovazione', 'rotondi', 'vincente', 'tecnologia'],
#  ['ministra', 'copiaampincolla', 'spiega', 'minaccia', 'fattoquotidiano'],
#  ['elogio', 'calcetto', 'unico', 'sport', 'mette', 'veramente', 'poletti'],
#  ['milionari',
#   'trasferiti',
#   'cerca',
#   'fisco',
#   'amico',
#   'focus',
#   'pagina',
#   'edicola'],
#  ['londonistan', 'tamigi', 'lintegrazione', 'funziona', 'parola', 'neocon'],
#  ['claudia', 'cardinale', 'poster', 'cannes', 'ritoccata', 'farla', 'magra'],
#  ['tetraplegico', 'torna', 'muovere', 'braccio', 'impianto', 'hitech'],
#  ['coreadelnord',
#   'ultimato',
#   'stadio',
#   'finale',
#   'sesto',
#   'nucleare',
#   'imminente'],
#  ['parchi',
#   'dibattito',
#   'legge',
#   'erealacci',
#   'italianostra',
#   'confrontano',
#   'proposta'],
#  ['washington', 'polizia', 'insegue', 'congresso', 'terrorismo'],
#  ['riconoscimento', 'facciale', 'usato', 'aeroporti'],
#  ['movimentoarturo', 'nasce', 'fenomeno', 'social'],
#  ['brexit',
#   'paletti',
#   'parlamento',
#   'europeo',
#   'discriminazioni',
#   'cittadini',
#   'britannici',
#   'gtgtgt'],
#  ['pirateria', 'difendere', 'copyright', 'torniamo', 'delazione'],
#  ['sputato', 'addosso', 'scialpi', 'insultato', 'strada'],
#  ['brexit', 'arriva', 'davvero', 'esultare'],
#  ['cirino', 'pomicino', 'giletti', 'guadagni', 'tangenti'],
#  ['dimentica',
#   'terremoto',
#   'appello',
#   'sindaci',
#   'cratere',
#   'comuni',
#   'rischiano',
#   'dissesto',
#   'guido',
#   'castelli'],
#  ['figlia', 'trump', 'assunta', 'assistente', 'bianca'],
#  ['turchia', 'terminato', 'campagna', 'militare', 'siria'],
#  ['corpi', 'intrecciati', 'lopera', 'darte', 'video'],
#  ['brexit', 'arrivata', 'cittadino', 'inglese', 'roberto', 'stasi'],
#  ['pacchetto',
#   'minniti',
#   'liberticida',
#   'copia',
#   'peggiori',
#   'destre',
#   'sbaglia',
#   'giacomo',
#   'russo',
#   'spena'],
#  ['disarmo',
#   'nucleare',
#   'scena',
#   'deserto',
#   'nuclearban',
#   'unconferencenuclearban',
#   'lavocedinewyork'],
#  ['patente', 'infrazioni', 'costano', 'punti'],
#  ['previsioni', 'meteo', 'gioved', 'marzo'],
#  ['pesante', 'turni', 'messi'],
#  ['piazza',
#   'under',
#   'disoccupazione',
#   'giovanile',
#   'vuole',
#   'risolvere',
#   'linkiesta'],
#  ['buongiorno',
#   'brexit',
#   'theresa',
#   'invoca',
#   'sulluscita',
#   'dallue',
#   'rassegna',
#   'mattino'],
#  ['marito',
#   'unelettrice',
#   'trump',
#   'lasciare',
#   'votato',
#   'perch',
#   'deporter',
#   'hombres'],
#  ['racconto',
#   'disperato',
#   'dellamico',
#   'emanuelemorganti',
#   'volevo',
#   'salvarlo',
#   'riuscito'],
#  ['renzi', 'batte', 'emiliano'],
#  ['protesta', 'notap', 'ferma', 'melendugno', 'tensioni', 'polizia'],
#  ['utili',
#   'ribasso',
#   'efficace',
#   'cattaneo',
#   'telecom',
#   'italia',
#   'notizie',
#   'economiche',
#   'settimana'],
#  ['tinder', 'versione'],
#  ['caserta',
#   'omicidiosuicidio',
#   'santa',
#   'maria',
#   'capua',
#   'vetere',
#   'trovati',
#   'morti',
#   'marito',
#   'moglie'],
#  ['moglie', 'franois', 'fillon', 'penelope', 'indagata'],
#  ['torna', 'single', 'notte'],
#  ['democrazia', 'diretta', 'perch', 'buona', 'marco', 'degidio'],
#  ['ritirano',
#   'acque',
#   'linondazione',
#   'foresta',
#   'compare',
#   'squalo',
#   'ciclonedebbie'],
#  ['pisano', 'spiega', 'mariodraghi', 'dovrebbe'],
#  ...]

# %%
te = TransactionEncoder()
te_ary = te.fit(list_final).transform(list_final)
df = pd.DataFrame(te_ary,columns=te.columns_)
frequent_items = apriori(df, min_support=0.001, use_colnames=True, max_len = 2)

# %%
print (frequent_items)
# Out:
#       support                       itemsets
# 0    0.001476                  (accaddeoggi)
# 1    0.001709                      (accordo)
# 2    0.001553                       (accusa)
# 3    0.001243                       (accuse)
# 4    0.003909                        (addio)
# 5    0.033213                    (adnkronos)
# 6    0.001035                        (aereo)
# 7    0.001087                       (affari)
# 8    0.001191                (affaritaliani)
# 9    0.001268                  (afghanistan)
# 10   0.001631                     (agenparl)
# 11   0.017396                  (agenziaansa)
# 12   0.001010                  (agenziadire)
# 13   0.005255                (agenziaitalia)
# 14   0.001087                      (agnelli)
# 15   0.001476                     (ahahahah)
# 16   0.001476                       (alatri)
# 17   0.001268                       (aleppo)
# 18   0.001476                       (alfano)
# 19   0.005876                     (alitalia)
# 20   0.001553                      (allarme)
# 21   0.001683                      (allegri)
# 22   0.003288                       (almeno)
# 23   0.001424                       (amanda)
# 24   0.001605                     (amatrice)
# 25   0.001165                       (amazon)
# 26   0.001709                      (america)
# 27   0.003236                        (amici)
# 28   0.001165                        (amore)
# 29   0.001010                       (andare)
# ..        ...                            ...
# 914  0.001786         (lastampatv, lastampa)
# 915  0.003572              (lastampa, video)
# 916  0.001838            (lastampatv, video)
# 917  0.001035              (libia, migranti)
# 918  0.001035              (renzi, lingotto)
# 919  0.001087          (westminster, londra)
# 920  0.001010            (quotidiano, marzo)
# 921  0.001501            (meteo, previsioni)
# 922  0.001450              (obama, michelle)
# 923  0.001087           (milano, repubblica)
# 924  0.001035            (morti, repubblica)
# 925  0.001631              (napoli, salvini)
# 926  0.001217               (renzi, orlando)
# 927  0.001217           (pagina, repubblica)
# 928  0.001398                (pagine, prime)
# 929  0.001734              (renzi, primarie)
# 930  0.001165       (radiotweet, radiomondo)
# 931  0.001605             (stampa, rassegna)
# 932  0.001346          (referendum, turchia)
# 933  0.001010            (renzi, repubblica)
# 934  0.001010     (repubblicait, repubblica)
# 935  0.002433            (trump, repubblica)
# 936  0.001035       (sabatocongress, sabato)
# 937  0.001372              (support, sabato)
# 938  0.002019          (sabato, terrebehlog)
# 939  0.001709      (support, sabatocongress)
# 940  0.001501  (sabatocongress, terrebehlog)
# 941  0.001993                 (siria, trump)
# 942  0.001398              (skytg, ultimora)
# 943  0.001941         (support, terrebehlog)
#
# [944 rows x 2 columns]

# %%
table = association_rules(frequent_items, metric="confidence", min_threshold=0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-833cac44a6ec> in <module>()
# ----> 1 table = association_rules(frequent_items, metric="confidence", min_threshold=0.7)
#
# NameError: name 'frequent_items' is not defined
